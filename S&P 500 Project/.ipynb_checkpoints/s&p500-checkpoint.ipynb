# %%
# Dependencies
import json
import os
from pprint import pprint
# Load JSON
filepath = os.path.join("stock.json")
with open(filepath) as jsonfile:
    json_data = json.load(jsonfile)
import pandas as pd

# %% [markdown]
# We imported the json file from https://datahub.io/core/s-and-p-500-companies

# %%
pprint(json_data)
# Out:
# [{'Name': '3M Company', 'Sector': 'Industrials', 'Symbol': 'MMM'},
#  {'Name': 'A.O. Smith Corp', 'Sector': 'Industrials', 'Symbol': 'AOS'},
#  {'Name': 'Abbott Laboratories', 'Sector': 'Health Care', 'Symbol': 'ABT'},
#  {'Name': 'AbbVie Inc.', 'Sector': 'Health Care', 'Symbol': 'ABBV'},
#  {'Name': 'Accenture plc', 'Sector': 'Information Technology', 'Symbol': 'ACN'},
#  {'Name': 'Activision Blizzard',
#   'Sector': 'Information Technology',
#   'Symbol': 'ATVI'},
#  {'Name': 'Acuity Brands Inc', 'Sector': 'Industrials', 'Symbol': 'AYI'},
#  {'Name': 'Adobe Systems Inc',
#   'Sector': 'Information Technology',
#   'Symbol': 'ADBE'},
#  {'Name': 'Advance Auto Parts',
#   'Sector': 'Consumer Discretionary',
#   'Symbol': 'AAP'},
#  {'Name': 'Advanced Micro Devices Inc',
#   'Sector': 'Information Technology',
#   'Symbol': 'AMD'},
#  {'Name': 'AES Corp', 'Sector': 'Utilities', 'Symbol': 'AES'},
#  {'Name': 'Aetna Inc', 'Sector': 'Health Care', 'Symbol': 'AET'},
#  {'Name': 'Affiliated Managers Group Inc',
#   'Sector': 'Financials',
#   'Symbol': 'AMG'},
#  {'Name': 'AFLAC Inc', 'Sector': 'Financials', 'Symbol': 'AFL'},
#  {'Name': 'Agilent Technologies Inc', 'Sector': 'Health Care', 'Symbol': 'A'},
#  {'Name': 'Air Products & Chemicals Inc',
#   'Sector': 'Materials',
#   'Symbol': 'APD'},
#  {'Name': 'Akamai Technologies Inc',
#   'Sector': 'Information Technology',
#   'Symbol': 'AKAM'},
#  {'Name': 'Alaska Air Group Inc', 'Sector': 'Industrials', 'Symbol': 'ALK'},
#  {'Name': 'Albemarle Corp', 'Sector': 'Materials', 'Symbol': 'ALB'},
#  {'Name': 'Alexandria Real Estate Equities Inc',
#   'Sector': 'Real Estate',
#   'Symbol': 'ARE'},
#  {'Name': 'Alexion Pharmaceuticals', 'Sector': 'Health Care', 'Symbol': 'ALXN'},
#  {'Name': 'Align Technology', 'Sector': 'Health Care', 'Symbol': 'ALGN'},
#  {'Name': 'Allegion', 'Sector': 'Industrials', 'Symbol': 'ALLE'},
#  {'Name': 'Allergan, Plc', 'Sector': 'Health Care', 'Symbol': 'AGN'},
#  {'Name': 'Alliance Data Systems',
#   'Sector': 'Information Technology',
#   'Symbol': 'ADS'},
#  {'Name': 'Alliant Energy Corp', 'Sector': 'Utilities', 'Symbol': 'LNT'},
#  {'Name': 'Allstate Corp', 'Sector': 'Financials', 'Symbol': 'ALL'},
#  {'Name': 'Alphabet Inc Class A',
#   'Sector': 'Information Technology',
#   'Symbol': 'GOOGL'},
#  {'Name': 'Alphabet Inc Class C',
#   'Sector': 'Information Technology',
#   'Symbol': 'GOOG'},
#  {'Name': 'Altria Group Inc', 'Sector': 'Consumer Staples', 'Symbol': 'MO'},
#  {'Name': 'Amazon.com Inc.',
#   'Sector': 'Consumer Discretionary',
#   'Symbol': 'AMZN'},
#  {'Name': 'Ameren Corp', 'Sector': 'Utilities', 'Symbol': 'AEE'},
#  {'Name': 'American Airlines Group', 'Sector': 'Industrials', 'Symbol': 'AAL'},
#  {'Name': 'American Electric Power', 'Sector': 'Utilities', 'Symbol': 'AEP'},
#  {'Name': 'American Express Co', 'Sector': 'Financials', 'Symbol': 'AXP'},
#  {'Name': 'American International Group, Inc.',
#   'Sector': 'Financials',
#   'Symbol': 'AIG'},
#  {'Name': 'American Tower Corp A', 'Sector': 'Real Estate', 'Symbol': 'AMT'},
#  {'Name': 'American Water Works Company Inc',
#   'Sector': 'Utilities',
#   'Symbol': 'AWK'},
#  {'Name': 'Ameriprise Financial', 'Sector': 'Financials', 'Symbol': 'AMP'},
#  {'Name': 'AmerisourceBergen Corp', 'Sector': 'Health Care', 'Symbol': 'ABC'},
#  {'Name': 'AMETEK Inc.', 'Sector': 'Industrials', 'Symbol': 'AME'},
#  {'Name': 'Amgen Inc.', 'Sector': 'Health Care', 'Symbol': 'AMGN'},
#  {'Name': 'Amphenol Corp', 'Sector': 'Information Technology', 'Symbol': 'APH'},
#  {'Name': 'Anadarko Petroleum Corp', 'Sector': 'Energy', 'Symbol': 'APC'},
#  {'Name': 'Analog Devices, Inc.',
#   'Sector': 'Information Technology',
#   'Symbol': 'ADI'},
#  {'Name': 'Andeavor', 'Sector': 'Energy', 'Symbol': 'ANDV'},
#  {'Name': 'ANSYS', 'Sector': 'Information Technology', 'Symbol': 'ANSS'},
#  {'Name': 'Anthem Inc.', 'Sector': 'Health Care', 'Symbol': 'ANTM'},
#  {'Name': 'Aon plc', 'Sector': 'Financials', 'Symbol': 'AON'},
#  {'Name': 'Apache Corporation', 'Sector': 'Energy', 'Symbol': 'APA'},
#  {'Name': 'Apartment Investment & Management',
#   'Sector': 'Real Estate',
#   'Symbol': 'AIV'},
#  {'Name': 'Apple Inc.', 'Sector': 'Information Technology', 'Symbol': 'AAPL'},
#  {'Name': 'Applied Materials Inc.',
#   'Sector': 'Information Technology',
#   'Symbol': 'AMAT'},
#  {'Name': 'Aptiv Plc', 'Sector': 'Consumer Discretionary', 'Symbol': 'APTV'},
#  {'Name': 'Archer-Daniels-Midland Co',
#   'Sector': 'Consumer Staples',
#   'Symbol': 'ADM'},
#  {'Name': 'Arconic Inc.', 'Sector': 'Industrials', 'Symbol': 'ARNC'},
#  {'Name': 'Arthur J. Gallagher & Co.', 'Sector': 'Financials', 'Symbol': 'AJG'},
#  {'Name': 'Assurant Inc.', 'Sector': 'Financials', 'Symbol': 'AIZ'},
#  {'Name': 'AT&T Inc.', 'Sector': 'Telecommunication Services', 'Symbol': 'T'},
#  {'Name': 'Autodesk Inc.',
#   'Sector': 'Information Technology',
#   'Symbol': 'ADSK'},
#  {'Name': 'Automatic Data Processing',
#   'Sector': 'Information Technology',
#   'Symbol': 'ADP'},
#  {'Name': 'AutoZone Inc', 'Sector': 'Consumer Discretionary', 'Symbol': 'AZO'},
#  {'Name': 'AvalonBay Communities, Inc.',
#   'Sector': 'Real Estate',
#   'Symbol': 'AVB'},
#  {'Name': 'Avery Dennison Corp', 'Sector': 'Materials', 'Symbol': 'AVY'},
#  {'Name': 'Baker Hughes, a GE Company', 'Sector': 'Energy', 'Symbol': 'BHGE'},
#  {'Name': 'Ball Corp', 'Sector': 'Materials', 'Symbol': 'BLL'},
#  {'Name': 'Bank of America Corp', 'Sector': 'Financials', 'Symbol': 'BAC'},
#  {'Name': 'Baxter International Inc.',
#   'Sector': 'Health Care',
#   'Symbol': 'BAX'},
#  {'Name': 'BB&T Corporation', 'Sector': 'Financials', 'Symbol': 'BBT'},
#  {'Name': 'Becton Dickinson', 'Sector': 'Health Care', 'Symbol': 'BDX'},
#  {'Name': 'Berkshire Hathaway', 'Sector': 'Financials', 'Symbol': 'BRK.B'},
#  {'Name': 'Best Buy Co. Inc.',
#   'Sector': 'Consumer Discretionary',
#   'Symbol': 'BBY'},
#  {'Name': 'Biogen Inc.', 'Sector': 'Health Care', 'Symbol': 'BIIB'},
#  {'Name': 'BlackRock', 'Sector': 'Financials', 'Symbol': 'BLK'},
#  {'Name': 'Block H&R', 'Sector': 'Financials', 'Symbol': 'HRB'},
#  {'Name': 'Boeing Company', 'Sector': 'Industrials', 'Symbol': 'BA'},
#  {'Name': 'Booking Holdings Inc',
#   'Sector': 'Consumer Discretionary',
#   'Symbol': 'BKNG'},
#  {'Name': 'BorgWarner', 'Sector': 'Consumer Discretionary', 'Symbol': 'BWA'},
#  {'Name': 'Boston Properties', 'Sector': 'Real Estate', 'Symbol': 'BXP'},
#  {'Name': 'Boston Scientific', 'Sector': 'Health Care', 'Symbol': 'BSX'},
#  {'Name': 'Brighthouse Financial Inc', 'Sector': 'Financials', 'Symbol': 'BHF'},
#  {'Name': 'Bristol-Myers Squibb', 'Sector': 'Health Care', 'Symbol': 'BMY'},
#  {'Name': 'Broadcom', 'Sector': 'Information Technology', 'Symbol': 'AVGO'},
#  {'Name': 'Brown-Forman Corp.', 'Sector': 'Consumer Staples', 'Symbol': 'BF.B'},
#  {'Name': 'C. H. Robinson Worldwide',
#   'Sector': 'Industrials',
#   'Symbol': 'CHRW'},
#  {'Name': 'CA, Inc.', 'Sector': 'Information Technology', 'Symbol': 'CA'},
#  {'Name': 'Cabot Oil & Gas', 'Sector': 'Energy', 'Symbol': 'COG'},
#  {'Name': 'Cadence Design Systems',
#   'Sector': 'Information Technology',
#   'Symbol': 'CDNS'},
#  {'Name': 'Campbell Soup', 'Sector': 'Consumer Staples', 'Symbol': 'CPB'},
#  {'Name': 'Capital One Financial', 'Sector': 'Financials', 'Symbol': 'COF'},
#  {'Name': 'Cardinal Health Inc.', 'Sector': 'Health Care', 'Symbol': 'CAH'},
#  {'Name': 'Carmax Inc', 'Sector': 'Consumer Discretionary', 'Symbol': 'KMX'},
#  {'Name': 'Carnival Corp.',
#   'Sector': 'Consumer Discretionary',
#   'Symbol': 'CCL'},
#  {'Name': 'Caterpillar Inc.', 'Sector': 'Industrials', 'Symbol': 'CAT'},
#  {'Name': 'Cboe Global Markets', 'Sector': 'Financials', 'Symbol': 'CBOE'},
#  {'Name': 'CBRE Group', 'Sector': 'Real Estate', 'Symbol': 'CBRE'},
#  {'Name': 'CBS Corp.', 'Sector': 'Consumer Discretionary', 'Symbol': 'CBS'},
#  {'Name': 'Celgene Corp.', 'Sector': 'Health Care', 'Symbol': 'CELG'},
#  {'Name': 'Centene Corporation', 'Sector': 'Health Care', 'Symbol': 'CNC'},
#  {'Name': 'CenterPoint Energy', 'Sector': 'Utilities', 'Symbol': 'CNP'},
#  {'Name': 'CenturyLink Inc',
#   'Sector': 'Telecommunication Services',
#   'Symbol': 'CTL'},
#  {'Name': 'Cerner', 'Sector': 'Health Care', 'Symbol': 'CERN'},
#  {'Name': 'CF Industries Holdings Inc', 'Sector': 'Materials', 'Symbol': 'CF'},
#  {'Name': 'Charles Schwab Corporation',
#   'Sector': 'Financials',
#   'Symbol': 'SCHW'},
#  {'Name': 'Charter Communications',
#   'Sector': 'Consumer Discretionary',
#   'Symbol': 'CHTR'},
#  {'Name': 'Chevron Corp.', 'Sector': 'Energy', 'Symbol': 'CVX'},
#  {'Name': 'Chipotle Mexican Grill',
#   'Sector': 'Consumer Discretionary',
#   'Symbol': 'CMG'},
#  {'Name': 'Chubb Limited', 'Sector': 'Financials', 'Symbol': 'CB'},
#  {'Name': 'Church & Dwight', 'Sector': 'Consumer Staples', 'Symbol': 'CHD'},
#  {'Name': 'CIGNA Corp.', 'Sector': 'Health Care', 'Symbol': 'CI'},
#  {'Name': 'Cimarex Energy', 'Sector': 'Energy', 'Symbol': 'XEC'},
#  {'Name': 'Cincinnati Financial', 'Sector': 'Financials', 'Symbol': 'CINF'},
#  {'Name': 'Cintas Corporation', 'Sector': 'Industrials', 'Symbol': 'CTAS'},
#  {'Name': 'Cisco Systems',
#   'Sector': 'Information Technology',
#   'Symbol': 'CSCO'},
#  {'Name': 'Citigroup Inc.', 'Sector': 'Financials', 'Symbol': 'C'},
#  {'Name': 'Citizens Financial Group', 'Sector': 'Financials', 'Symbol': 'CFG'},
#  {'Name': 'Citrix Systems',
#   'Sector': 'Information Technology',
#   'Symbol': 'CTXS'},
#  {'Name': 'CME Group Inc.', 'Sector': 'Financials', 'Symbol': 'CME'},
#  {'Name': 'CMS Energy', 'Sector': 'Utilities', 'Symbol': 'CMS'},
#  {'Name': 'Coca-Cola Company (The)',
#   'Sector': 'Consumer Staples',
#   'Symbol': 'KO'},
#  {'Name': 'Cognizant Technology Solutions',
#   'Sector': 'Information Technology',
#   'Symbol': 'CTSH'},
#  {'Name': 'Colgate-Palmolive', 'Sector': 'Consumer Staples', 'Symbol': 'CL'},
#  {'Name': 'Comcast Corp.',
#   'Sector': 'Consumer Discretionary',
#   'Symbol': 'CMCSA'},
#  {'Name': 'Comerica Inc.', 'Sector': 'Financials', 'Symbol': 'CMA'},
#  {'Name': 'Conagra Brands', 'Sector': 'Consumer Staples', 'Symbol': 'CAG'},
#  {'Name': 'Concho Resources', 'Sector': 'Energy', 'Symbol': 'CXO'},
#  {'Name': 'ConocoPhillips', 'Sector': 'Energy', 'Symbol': 'COP'},
#  {'Name': 'Consolidated Edison', 'Sector': 'Utilities', 'Symbol': 'ED'},
#  {'Name': 'Constellation Brands',
#   'Sector': 'Consumer Staples',
#   'Symbol': 'STZ'},
#  {'Name': 'Corning Inc.', 'Sector': 'Information Technology', 'Symbol': 'GLW'},
#  {'Name': 'Costco Wholesale Corp.',
#   'Sector': 'Consumer Staples',
#   'Symbol': 'COST'},
#  {'Name': 'Coty, Inc', 'Sector': 'Consumer Staples', 'Symbol': 'COTY'},
#  {'Name': 'Crown Castle International Corp.',
#   'Sector': 'Real Estate',
#   'Symbol': 'CCI'},
#  {'Name': 'CSRA Inc.', 'Sector': 'Information Technology', 'Symbol': 'CSRA'},
#  {'Name': 'CSX Corp.', 'Sector': 'Industrials', 'Symbol': 'CSX'},
#  {'Name': 'Cummins Inc.', 'Sector': 'Industrials', 'Symbol': 'CMI'},
#  {'Name': 'CVS Health', 'Sector': 'Consumer Staples', 'Symbol': 'CVS'},
#  {'Name': 'D. R. Horton', 'Sector': 'Consumer Discretionary', 'Symbol': 'DHI'},
#  {'Name': 'Danaher Corp.', 'Sector': 'Health Care', 'Symbol': 'DHR'},
#  {'Name': 'Darden Restaurants',
#   'Sector': 'Consumer Discretionary',
#   'Symbol': 'DRI'},
#  {'Name': 'DaVita Inc.', 'Sector': 'Health Care', 'Symbol': 'DVA'},
#  {'Name': 'Deere & Co.', 'Sector': 'Industrials', 'Symbol': 'DE'},
#  {'Name': 'Delta Air Lines Inc.', 'Sector': 'Industrials', 'Symbol': 'DAL'},
#  {'Name': 'Dentsply Sirona', 'Sector': 'Health Care', 'Symbol': 'XRAY'},
#  {'Name': 'Devon Energy Corp.', 'Sector': 'Energy', 'Symbol': 'DVN'},
#  {'Name': 'Digital Realty Trust Inc', 'Sector': 'Real Estate', 'Symbol': 'DLR'},
#  {'Name': 'Discover Financial Services',
#   'Sector': 'Financials',
#   'Symbol': 'DFS'},
#  {'Name': 'Discovery Inc. Class A',
#   'Sector': 'Consumer Discretionary',
#   'Symbol': 'DISCA'},
#  {'Name': 'Discovery Inc. Class C',
#   'Sector': 'Consumer Discretionary',
#   'Symbol': 'DISCK'},
#  {'Name': 'Dish Network', 'Sector': 'Consumer Discretionary', 'Symbol': 'DISH'},
#  {'Name': 'Dollar General', 'Sector': 'Consumer Discretionary', 'Symbol': 'DG'},
#  {'Name': 'Dollar Tree', 'Sector': 'Consumer Discretionary', 'Symbol': 'DLTR'},
#  {'Name': 'Dominion Energy', 'Sector': 'Utilities', 'Symbol': 'D'},
#  {'Name': 'Dover Corp.', 'Sector': 'Industrials', 'Symbol': 'DOV'},
#  {'Name': 'DowDuPont', 'Sector': 'Materials', 'Symbol': 'DWDP'},
#  {'Name': 'Dr Pepper Snapple Group',
#   'Sector': 'Consumer Staples',
#   'Symbol': 'DPS'},
#  {'Name': 'DTE Energy Co.', 'Sector': 'Utilities', 'Symbol': 'DTE'},
#  {'Name': 'Duke Energy', 'Sector': 'Utilities', 'Symbol': 'DUK'},
#  {'Name': 'Duke Realty Corp', 'Sector': 'Real Estate', 'Symbol': 'DRE'},
#  {'Name': 'DXC Technology',
#   'Sector': 'Information Technology',
#   'Symbol': 'DXC'},
#  {'Name': 'E*Trade', 'Sector': 'Financials', 'Symbol': 'ETFC'},
#  {'Name': 'Eastman Chemical', 'Sector': 'Materials', 'Symbol': 'EMN'},
#  {'Name': 'Eaton Corporation', 'Sector': 'Industrials', 'Symbol': 'ETN'},
#  {'Name': 'eBay Inc.', 'Sector': 'Information Technology', 'Symbol': 'EBAY'},
#  {'Name': 'Ecolab Inc.', 'Sector': 'Materials', 'Symbol': 'ECL'},
#  {'Name': "Edison Int'l", 'Sector': 'Utilities', 'Symbol': 'EIX'},
#  {'Name': 'Edwards Lifesciences', 'Sector': 'Health Care', 'Symbol': 'EW'},
#  {'Name': 'Electronic Arts',
#   'Sector': 'Information Technology',
#   'Symbol': 'EA'},
#  {'Name': 'Emerson Electric Company', 'Sector': 'Industrials', 'Symbol': 'EMR'},
#  {'Name': 'Entergy Corp.', 'Sector': 'Utilities', 'Symbol': 'ETR'},
#  {'Name': 'Envision Healthcare', 'Sector': 'Health Care', 'Symbol': 'EVHC'},
#  {'Name': 'EOG Resources', 'Sector': 'Energy', 'Symbol': 'EOG'},
#  {'Name': 'EQT Corporation', 'Sector': 'Energy', 'Symbol': 'EQT'},
#  {'Name': 'Equifax Inc.', 'Sector': 'Industrials', 'Symbol': 'EFX'},
#  {'Name': 'Equinix', 'Sector': 'Real Estate', 'Symbol': 'EQIX'},
#  {'Name': 'Equity Residential', 'Sector': 'Real Estate', 'Symbol': 'EQR'},
#  {'Name': 'Essex Property Trust, Inc.',
#   'Sector': 'Real Estate',
#   'Symbol': 'ESS'},
#  {'Name': 'Estee Lauder Cos.', 'Sector': 'Consumer Staples', 'Symbol': 'EL'},
#  {'Name': 'Everest Re Group Ltd.', 'Sector': 'Financials', 'Symbol': 'RE'},
#  {'Name': 'Eversource Energy', 'Sector': 'Utilities', 'Symbol': 'ES'},
#  {'Name': 'Exelon Corp.', 'Sector': 'Utilities', 'Symbol': 'EXC'},
#  {'Name': 'Expedia Inc.', 'Sector': 'Consumer Discretionary', 'Symbol': 'EXPE'},
#  {'Name': 'Expeditors International',
#   'Sector': 'Industrials',
#   'Symbol': 'EXPD'},
#  {'Name': 'Express Scripts', 'Sector': 'Health Care', 'Symbol': 'ESRX'},
#  {'Name': 'Extra Space Storage', 'Sector': 'Real Estate', 'Symbol': 'EXR'},
#  {'Name': 'Exxon Mobil Corp.', 'Sector': 'Energy', 'Symbol': 'XOM'},
#  {'Name': 'F5 Networks', 'Sector': 'Information Technology', 'Symbol': 'FFIV'},
#  {'Name': 'Facebook, Inc.', 'Sector': 'Information Technology', 'Symbol': 'FB'},
#  {'Name': 'Fastenal Co', 'Sector': 'Industrials', 'Symbol': 'FAST'},
#  {'Name': 'Federal Realty Investment Trust',
#   'Sector': 'Real Estate',
#   'Symbol': 'FRT'},
#  {'Name': 'FedEx Corporation', 'Sector': 'Industrials', 'Symbol': 'FDX'},
#  {'Name': 'Fidelity National Information Services',
#   'Sector': 'Information Technology',
#   'Symbol': 'FIS'},
#  {'Name': 'Fifth Third Bancorp', 'Sector': 'Financials', 'Symbol': 'FITB'},
#  {'Name': 'FirstEnergy Corp', 'Sector': 'Utilities', 'Symbol': 'FE'},
#  {'Name': 'Fiserv Inc', 'Sector': 'Information Technology', 'Symbol': 'FISV'},
#  {'Name': 'FLIR Systems', 'Sector': 'Information Technology', 'Symbol': 'FLIR'},
#  {'Name': 'Flowserve Corporation', 'Sector': 'Industrials', 'Symbol': 'FLS'},
#  {'Name': 'Fluor Corp.', 'Sector': 'Industrials', 'Symbol': 'FLR'},
#  {'Name': 'FMC Corporation', 'Sector': 'Materials', 'Symbol': 'FMC'},
#  {'Name': 'Foot Locker Inc',
#   'Sector': 'Consumer Discretionary',
#   'Symbol': 'FL'},
#  {'Name': 'Ford Motor', 'Sector': 'Consumer Discretionary', 'Symbol': 'F'},
#  {'Name': 'Fortive Corp', 'Sector': 'Industrials', 'Symbol': 'FTV'},
#  {'Name': 'Fortune Brands Home & Security',
#   'Sector': 'Industrials',
#   'Symbol': 'FBHS'},
#  {'Name': 'Franklin Resources', 'Sector': 'Financials', 'Symbol': 'BEN'},
#  {'Name': 'Freeport-McMoRan Inc.', 'Sector': 'Materials', 'Symbol': 'FCX'},
#  {'Name': 'Gap Inc.', 'Sector': 'Consumer Discretionary', 'Symbol': 'GPS'},
#  {'Name': 'Garmin Ltd.', 'Sector': 'Consumer Discretionary', 'Symbol': 'GRMN'},
#  {'Name': 'Gartner Inc', 'Sector': 'Information Technology', 'Symbol': 'IT'},
#  {'Name': 'General Dynamics', 'Sector': 'Industrials', 'Symbol': 'GD'},
#  {'Name': 'General Electric', 'Sector': 'Industrials', 'Symbol': 'GE'},
#  {'Name': 'General Growth Properties Inc.',
#   'Sector': 'Real Estate',
#   'Symbol': 'GGP'},
#  {'Name': 'General Mills', 'Sector': 'Consumer Staples', 'Symbol': 'GIS'},
#  {'Name': 'General Motors', 'Sector': 'Consumer Discretionary', 'Symbol': 'GM'},
#  {'Name': 'Genuine Parts', 'Sector': 'Consumer Discretionary', 'Symbol': 'GPC'},
#  {'Name': 'Gilead Sciences', 'Sector': 'Health Care', 'Symbol': 'GILD'},
#  {'Name': 'Global Payments Inc.',
#   'Sector': 'Information Technology',
#   'Symbol': 'GPN'},
#  {'Name': 'Goldman Sachs Group', 'Sector': 'Financials', 'Symbol': 'GS'},
#  {'Name': 'Goodyear Tire & Rubber',
#   'Sector': 'Consumer Discretionary',
#   'Symbol': 'GT'},
#  {'Name': 'Grainger (W.W.) Inc.', 'Sector': 'Industrials', 'Symbol': 'GWW'},
#  {'Name': 'Halliburton Co.', 'Sector': 'Energy', 'Symbol': 'HAL'},
#  {'Name': 'Hanesbrands Inc',
#   'Sector': 'Consumer Discretionary',
#   'Symbol': 'HBI'},
#  {'Name': 'Harley-Davidson',
#   'Sector': 'Consumer Discretionary',
#   'Symbol': 'HOG'},
#  {'Name': 'Harris Corporation',
#   'Sector': 'Information Technology',
#   'Symbol': 'HRS'},
#  {'Name': 'Hartford Financial Svc.Gp.',
#   'Sector': 'Financials',
#   'Symbol': 'HIG'},
#  {'Name': 'Hasbro Inc.', 'Sector': 'Consumer Discretionary', 'Symbol': 'HAS'},
#  {'Name': 'HCA Holdings', 'Sector': 'Health Care', 'Symbol': 'HCA'},
#  {'Name': 'HCP Inc.', 'Sector': 'Real Estate', 'Symbol': 'HCP'},
#  {'Name': 'Helmerich & Payne', 'Sector': 'Energy', 'Symbol': 'HP'},
#  {'Name': 'Henry Schein', 'Sector': 'Health Care', 'Symbol': 'HSIC'},
#  {'Name': 'Hess Corporation', 'Sector': 'Energy', 'Symbol': 'HES'},
#  {'Name': 'Hewlett Packard Enterprise',
#   'Sector': 'Information Technology',
#   'Symbol': 'HPE'},
#  {'Name': 'Hilton Worldwide Holdings Inc',
#   'Sector': 'Consumer Discretionary',
#   'Symbol': 'HLT'},
#  {'Name': 'Hologic', 'Sector': 'Health Care', 'Symbol': 'HOLX'},
#  {'Name': 'Home Depot', 'Sector': 'Consumer Discretionary', 'Symbol': 'HD'},
#  {'Name': "Honeywell Int'l Inc.", 'Sector': 'Industrials', 'Symbol': 'HON'},
#  {'Name': 'Hormel Foods Corp.', 'Sector': 'Consumer Staples', 'Symbol': 'HRL'},
#  {'Name': 'Host Hotels & Resorts', 'Sector': 'Real Estate', 'Symbol': 'HST'},
#  {'Name': 'HP Inc.', 'Sector': 'Information Technology', 'Symbol': 'HPQ'},
#  {'Name': 'Humana Inc.', 'Sector': 'Health Care', 'Symbol': 'HUM'},
#  {'Name': 'Huntington Bancshares', 'Sector': 'Financials', 'Symbol': 'HBAN'},
#  {'Name': 'Huntington Ingalls Industries',
#   'Sector': 'Industrials',
#   'Symbol': 'HII'},
#  {'Name': 'IDEXX Laboratories', 'Sector': 'Health Care', 'Symbol': 'IDXX'},
#  {'Name': 'IHS Markit Ltd.', 'Sector': 'Industrials', 'Symbol': 'INFO'},
#  {'Name': 'Illinois Tool Works', 'Sector': 'Industrials', 'Symbol': 'ITW'},
#  {'Name': 'Illumina Inc', 'Sector': 'Health Care', 'Symbol': 'ILMN'},
#  {'Name': 'Incyte', 'Sector': 'Health Care', 'Symbol': 'INCY'},
#  {'Name': 'Ingersoll-Rand PLC', 'Sector': 'Industrials', 'Symbol': 'IR'},
#  {'Name': 'Intel Corp.', 'Sector': 'Information Technology', 'Symbol': 'INTC'},
#  {'Name': 'Intercontinental Exchange', 'Sector': 'Financials', 'Symbol': 'ICE'},
#  {'Name': 'International Business Machines',
#   'Sector': 'Information Technology',
#   'Symbol': 'IBM'},
#  {'Name': 'International Paper', 'Sector': 'Materials', 'Symbol': 'IP'},
#  {'Name': 'Interpublic Group',
#   'Sector': 'Consumer Discretionary',
#   'Symbol': 'IPG'},
#  {'Name': 'Intl Flavors & Fragrances', 'Sector': 'Materials', 'Symbol': 'IFF'},
#  {'Name': 'Intuit Inc.', 'Sector': 'Information Technology', 'Symbol': 'INTU'},
#  {'Name': 'Intuitive Surgical Inc.', 'Sector': 'Health Care', 'Symbol': 'ISRG'},
#  {'Name': 'Invesco Ltd.', 'Sector': 'Financials', 'Symbol': 'IVZ'},
#  {'Name': 'IPG Photonics Corp.',
#   'Sector': 'Information Technology',
#   'Symbol': 'IPGP'},
#  {'Name': 'IQVIA Holdings Inc.', 'Sector': 'Health Care', 'Symbol': 'IQV'},
#  {'Name': 'Iron Mountain Incorporated',
#   'Sector': 'Real Estate',
#   'Symbol': 'IRM'},
#  {'Name': 'J. B. Hunt Transport Services',
#   'Sector': 'Industrials',
#   'Symbol': 'JBHT'},
#  {'Name': 'Jacobs Engineering Group', 'Sector': 'Industrials', 'Symbol': 'JEC'},
#  {'Name': 'JM Smucker', 'Sector': 'Consumer Staples', 'Symbol': 'SJM'},
#  {'Name': 'Johnson & Johnson', 'Sector': 'Health Care', 'Symbol': 'JNJ'},
#  {'Name': 'Johnson Controls International',
#   'Sector': 'Industrials',
#   'Symbol': 'JCI'},
#  {'Name': 'JPMorgan Chase & Co.', 'Sector': 'Financials', 'Symbol': 'JPM'},
#  {'Name': 'Juniper Networks',
#   'Sector': 'Information Technology',
#   'Symbol': 'JNPR'},
#  {'Name': 'Kansas City Southern', 'Sector': 'Industrials', 'Symbol': 'KSU'},
#  {'Name': 'Kellogg Co.', 'Sector': 'Consumer Staples', 'Symbol': 'K'},
#  {'Name': 'KeyCorp', 'Sector': 'Financials', 'Symbol': 'KEY'},
#  {'Name': 'Kimberly-Clark', 'Sector': 'Consumer Staples', 'Symbol': 'KMB'},
#  {'Name': 'Kimco Realty', 'Sector': 'Real Estate', 'Symbol': 'KIM'},
#  {'Name': 'Kinder Morgan', 'Sector': 'Energy', 'Symbol': 'KMI'},
#  {'Name': 'KLA-Tencor Corp.',
#   'Sector': 'Information Technology',
#   'Symbol': 'KLAC'},
#  {'Name': "Kohl's Corp.", 'Sector': 'Consumer Discretionary', 'Symbol': 'KSS'},
#  {'Name': 'Kraft Heinz Co', 'Sector': 'Consumer Staples', 'Symbol': 'KHC'},
#  {'Name': 'Kroger Co.', 'Sector': 'Consumer Staples', 'Symbol': 'KR'},
#  {'Name': 'L Brands Inc.', 'Sector': 'Consumer Discretionary', 'Symbol': 'LB'},
#  {'Name': 'L-3 Communications Holdings',
#   'Sector': 'Industrials',
#   'Symbol': 'LLL'},
#  {'Name': 'Laboratory Corp. of America Holding',
#   'Sector': 'Health Care',
#   'Symbol': 'LH'},
#  {'Name': 'Lam Research', 'Sector': 'Information Technology', 'Symbol': 'LRCX'},
#  {'Name': 'Leggett & Platt',
#   'Sector': 'Consumer Discretionary',
#   'Symbol': 'LEG'},
#  {'Name': 'Lennar Corp.', 'Sector': 'Consumer Discretionary', 'Symbol': 'LEN'},
#  {'Name': 'Leucadia National Corp.', 'Sector': 'Financials', 'Symbol': 'LUK'},
#  {'Name': 'Lilly (Eli) & Co.', 'Sector': 'Health Care', 'Symbol': 'LLY'},
#  {'Name': 'Lincoln National', 'Sector': 'Financials', 'Symbol': 'LNC'},
#  {'Name': 'LKQ Corporation',
#   'Sector': 'Consumer Discretionary',
#   'Symbol': 'LKQ'},
#  {'Name': 'Lockheed Martin Corp.', 'Sector': 'Industrials', 'Symbol': 'LMT'},
#  {'Name': 'Loews Corp.', 'Sector': 'Financials', 'Symbol': 'L'},
#  {'Name': "Lowe's Cos.", 'Sector': 'Consumer Discretionary', 'Symbol': 'LOW'},
#  {'Name': 'LyondellBasell', 'Sector': 'Materials', 'Symbol': 'LYB'},
#  {'Name': 'M&T Bank Corp.', 'Sector': 'Financials', 'Symbol': 'MTB'},
#  {'Name': 'Macerich', 'Sector': 'Real Estate', 'Symbol': 'MAC'},
#  {'Name': "Macy's Inc.", 'Sector': 'Consumer Discretionary', 'Symbol': 'M'},
#  {'Name': 'Marathon Oil Corp.', 'Sector': 'Energy', 'Symbol': 'MRO'},
#  {'Name': 'Marathon Petroleum', 'Sector': 'Energy', 'Symbol': 'MPC'},
#  {'Name': "Marriott Int'l.",
#   'Sector': 'Consumer Discretionary',
#   'Symbol': 'MAR'},
#  {'Name': 'Marsh & McLennan', 'Sector': 'Financials', 'Symbol': 'MMC'},
#  {'Name': 'Martin Marietta Materials', 'Sector': 'Materials', 'Symbol': 'MLM'},
#  {'Name': 'Masco Corp.', 'Sector': 'Industrials', 'Symbol': 'MAS'},
#  {'Name': 'Mastercard Inc.',
#   'Sector': 'Information Technology',
#   'Symbol': 'MA'},
#  {'Name': 'Mattel Inc.', 'Sector': 'Consumer Discretionary', 'Symbol': 'MAT'},
#  {'Name': 'McCormick & Co.', 'Sector': 'Consumer Staples', 'Symbol': 'MKC'},
#  {'Name': "McDonald's Corp.",
#   'Sector': 'Consumer Discretionary',
#   'Symbol': 'MCD'},
#  {'Name': 'McKesson Corp.', 'Sector': 'Health Care', 'Symbol': 'MCK'},
#  {'Name': 'Medtronic plc', 'Sector': 'Health Care', 'Symbol': 'MDT'},
#  {'Name': 'Merck & Co.', 'Sector': 'Health Care', 'Symbol': 'MRK'},
#  {'Name': 'MetLife Inc.', 'Sector': 'Financials', 'Symbol': 'MET'},
#  {'Name': 'Mettler Toledo', 'Sector': 'Health Care', 'Symbol': 'MTD'},
#  {'Name': 'MGM Resorts International',
#   'Sector': 'Consumer Discretionary',
#   'Symbol': 'MGM'},
#  {'Name': 'Michael Kors Holdings',
#   'Sector': 'Consumer Discretionary',
#   'Symbol': 'KORS'},
#  {'Name': 'Microchip Technology',
#   'Sector': 'Information Technology',
#   'Symbol': 'MCHP'},
#  {'Name': 'Micron Technology',
#   'Sector': 'Information Technology',
#   'Symbol': 'MU'},
#  {'Name': 'Microsoft Corp.',
#   'Sector': 'Information Technology',
#   'Symbol': 'MSFT'},
#  {'Name': 'Mid-America Apartments', 'Sector': 'Real Estate', 'Symbol': 'MAA'},
#  {'Name': 'Mohawk Industries',
#   'Sector': 'Consumer Discretionary',
#   'Symbol': 'MHK'},
#  {'Name': 'Molson Coors Brewing Company',
#   'Sector': 'Consumer Staples',
#   'Symbol': 'TAP'},
#  {'Name': 'Mondelez International',
#   'Sector': 'Consumer Staples',
#   'Symbol': 'MDLZ'},
#  {'Name': 'Monsanto Co.', 'Sector': 'Materials', 'Symbol': 'MON'},
#  {'Name': 'Monster Beverage', 'Sector': 'Consumer Staples', 'Symbol': 'MNST'},
#  {'Name': "Moody's Corp", 'Sector': 'Financials', 'Symbol': 'MCO'},
#  {'Name': 'Morgan Stanley', 'Sector': 'Financials', 'Symbol': 'MS'},
#  {'Name': 'Motorola Solutions Inc.',
#   'Sector': 'Information Technology',
#   'Symbol': 'MSI'},
#  {'Name': 'Mylan N.V.', 'Sector': 'Health Care', 'Symbol': 'MYL'},
#  {'Name': 'Nasdaq, Inc.', 'Sector': 'Financials', 'Symbol': 'NDAQ'},
#  {'Name': 'National Oilwell Varco Inc.', 'Sector': 'Energy', 'Symbol': 'NOV'},
#  {'Name': 'Navient', 'Sector': 'Financials', 'Symbol': 'NAVI'},
#  {'Name': 'Nektar Therapeutics', 'Sector': 'Health Care', 'Symbol': 'NKTR'},
#  {'Name': 'NetApp', 'Sector': 'Information Technology', 'Symbol': 'NTAP'},
#  {'Name': 'Netflix Inc.', 'Sector': 'Information Technology', 'Symbol': 'NFLX'},
#  {'Name': 'Newell Brands', 'Sector': 'Consumer Discretionary', 'Symbol': 'NWL'},
#  {'Name': 'Newfield Exploration Co', 'Sector': 'Energy', 'Symbol': 'NFX'},
#  {'Name': 'Newmont Mining Corporation', 'Sector': 'Materials', 'Symbol': 'NEM'},
#  {'Name': 'News Corp. Class A',
#   'Sector': 'Consumer Discretionary',
#   'Symbol': 'NWSA'},
#  {'Name': 'News Corp. Class B',
#   'Sector': 'Consumer Discretionary',
#   'Symbol': 'NWS'},
#  {'Name': 'NextEra Energy', 'Sector': 'Utilities', 'Symbol': 'NEE'},
#  {'Name': 'Nielsen Holdings', 'Sector': 'Industrials', 'Symbol': 'NLSN'},
#  {'Name': 'Nike', 'Sector': 'Consumer Discretionary', 'Symbol': 'NKE'},
#  {'Name': 'NiSource Inc.', 'Sector': 'Utilities', 'Symbol': 'NI'},
#  {'Name': 'Noble Energy Inc', 'Sector': 'Energy', 'Symbol': 'NBL'},
#  {'Name': 'Nordstrom', 'Sector': 'Consumer Discretionary', 'Symbol': 'JWN'},
#  {'Name': 'Norfolk Southern Corp.', 'Sector': 'Industrials', 'Symbol': 'NSC'},
#  {'Name': 'Northern Trust Corp.', 'Sector': 'Financials', 'Symbol': 'NTRS'},
#  {'Name': 'Northrop Grumman Corp.', 'Sector': 'Industrials', 'Symbol': 'NOC'},
#  {'Name': 'Norwegian Cruise Line',
#   'Sector': 'Consumer Discretionary',
#   'Symbol': 'NCLH'},
#  {'Name': 'NRG Energy', 'Sector': 'Utilities', 'Symbol': 'NRG'},
#  {'Name': 'Nucor Corp.', 'Sector': 'Materials', 'Symbol': 'NUE'},
#  {'Name': 'Nvidia Corporation',
#   'Sector': 'Information Technology',
#   'Symbol': 'NVDA'},
#  {'Name': "O'Reilly Automotive",
#   'Sector': 'Consumer Discretionary',
#   'Symbol': 'ORLY'},
#  {'Name': 'Occidental Petroleum', 'Sector': 'Energy', 'Symbol': 'OXY'},
#  {'Name': 'Omnicom Group', 'Sector': 'Consumer Discretionary', 'Symbol': 'OMC'},
#  {'Name': 'ONEOK', 'Sector': 'Energy', 'Symbol': 'OKE'},
#  {'Name': 'Oracle Corp.', 'Sector': 'Information Technology', 'Symbol': 'ORCL'},
#  {'Name': 'PACCAR Inc.', 'Sector': 'Industrials', 'Symbol': 'PCAR'},
#  {'Name': 'Packaging Corporation of America',
#   'Sector': 'Materials',
#   'Symbol': 'PKG'},
#  {'Name': 'Parker-Hannifin', 'Sector': 'Industrials', 'Symbol': 'PH'},
#  {'Name': 'Paychex Inc.', 'Sector': 'Information Technology', 'Symbol': 'PAYX'},
#  {'Name': 'PayPal', 'Sector': 'Information Technology', 'Symbol': 'PYPL'},
#  {'Name': 'Pentair Ltd.', 'Sector': 'Industrials', 'Symbol': 'PNR'},
#  {'Name': "People's United Financial",
#   'Sector': 'Financials',
#   'Symbol': 'PBCT'},
#  {'Name': 'PepsiCo Inc.', 'Sector': 'Consumer Staples', 'Symbol': 'PEP'},
#  {'Name': 'PerkinElmer', 'Sector': 'Health Care', 'Symbol': 'PKI'},
#  {'Name': 'Perrigo', 'Sector': 'Health Care', 'Symbol': 'PRGO'},
#  {'Name': 'Pfizer Inc.', 'Sector': 'Health Care', 'Symbol': 'PFE'},
#  {'Name': 'PG&E Corp.', 'Sector': 'Utilities', 'Symbol': 'PCG'},
#  {'Name': 'Philip Morris International',
#   'Sector': 'Consumer Staples',
#   'Symbol': 'PM'},
#  {'Name': 'Phillips 66', 'Sector': 'Energy', 'Symbol': 'PSX'},
#  {'Name': 'Pinnacle West Capital', 'Sector': 'Utilities', 'Symbol': 'PNW'},
#  {'Name': 'Pioneer Natural Resources', 'Sector': 'Energy', 'Symbol': 'PXD'},
#  {'Name': 'PNC Financial Services', 'Sector': 'Financials', 'Symbol': 'PNC'},
#  {'Name': 'Polo Ralph Lauren Corp.',
#   'Sector': 'Consumer Discretionary',
#   'Symbol': 'RL'},
#  {'Name': 'PPG Industries', 'Sector': 'Materials', 'Symbol': 'PPG'},
#  {'Name': 'PPL Corp.', 'Sector': 'Utilities', 'Symbol': 'PPL'},
#  {'Name': 'Praxair Inc.', 'Sector': 'Materials', 'Symbol': 'PX'},
#  {'Name': 'Principal Financial Group', 'Sector': 'Financials', 'Symbol': 'PFG'},
#  {'Name': 'Procter & Gamble', 'Sector': 'Consumer Staples', 'Symbol': 'PG'},
#  {'Name': 'Progressive Corp.', 'Sector': 'Financials', 'Symbol': 'PGR'},
#  {'Name': 'Prologis', 'Sector': 'Real Estate', 'Symbol': 'PLD'},
#  {'Name': 'Prudential Financial', 'Sector': 'Financials', 'Symbol': 'PRU'},
#  {'Name': 'Public Serv. Enterprise Inc.',
#   'Sector': 'Utilities',
#   'Symbol': 'PEG'},
#  {'Name': 'Public Storage', 'Sector': 'Real Estate', 'Symbol': 'PSA'},
#  {'Name': 'Pulte Homes Inc.',
#   'Sector': 'Consumer Discretionary',
#   'Symbol': 'PHM'},
#  {'Name': 'PVH Corp.', 'Sector': 'Consumer Discretionary', 'Symbol': 'PVH'},
#  {'Name': 'Qorvo', 'Sector': 'Information Technology', 'Symbol': 'QRVO'},
#  {'Name': 'QUALCOMM Inc.',
#   'Sector': 'Information Technology',
#   'Symbol': 'QCOM'},
#  {'Name': 'Quanta Services Inc.', 'Sector': 'Industrials', 'Symbol': 'PWR'},
#  {'Name': 'Quest Diagnostics', 'Sector': 'Health Care', 'Symbol': 'DGX'},
#  {'Name': 'Range Resources Corp.', 'Sector': 'Energy', 'Symbol': 'RRC'},
#  {'Name': 'Raymond James Financial Inc.',
#   'Sector': 'Financials',
#   'Symbol': 'RJF'},
#  {'Name': 'Raytheon Co.', 'Sector': 'Industrials', 'Symbol': 'RTN'},
#  {'Name': 'Realty Income Corporation', 'Sector': 'Real Estate', 'Symbol': 'O'},
#  {'Name': 'Red Hat Inc.', 'Sector': 'Information Technology', 'Symbol': 'RHT'},
#  {'Name': 'Regency Centers Corporation',
#   'Sector': 'Real Estate',
#   'Symbol': 'REG'},
#  {'Name': 'Regeneron', 'Sector': 'Health Care', 'Symbol': 'REGN'},
#  {'Name': 'Regions Financial Corp.', 'Sector': 'Financials', 'Symbol': 'RF'},
#  {'Name': 'Republic Services Inc', 'Sector': 'Industrials', 'Symbol': 'RSG'},
#  {'Name': 'ResMed', 'Sector': 'Health Care', 'Symbol': 'RMD'},
#  {'Name': 'Robert Half International',
#   'Sector': 'Industrials',
#   'Symbol': 'RHI'},
#  {'Name': 'Rockwell Automation Inc.', 'Sector': 'Industrials', 'Symbol': 'ROK'},
#  {'Name': 'Rockwell Collins', 'Sector': 'Industrials', 'Symbol': 'COL'},
#  {'Name': 'Roper Technologies', 'Sector': 'Industrials', 'Symbol': 'ROP'},
#  {'Name': 'Ross Stores', 'Sector': 'Consumer Discretionary', 'Symbol': 'ROST'},
#  {'Name': 'Royal Caribbean Cruises Ltd',
#   'Sector': 'Consumer Discretionary',
#   'Symbol': 'RCL'},
#  {'Name': 'S&P Global, Inc.', 'Sector': 'Financials', 'Symbol': 'SPGI'},
#  {'Name': 'Salesforce.com',
#   'Sector': 'Information Technology',
#   'Symbol': 'CRM'},
#  {'Name': 'SBA Communications', 'Sector': 'Real Estate', 'Symbol': 'SBAC'},
#  {'Name': 'SCANA Corp', 'Sector': 'Utilities', 'Symbol': 'SCG'},
#  {'Name': 'Schlumberger Ltd.', 'Sector': 'Energy', 'Symbol': 'SLB'},
#  {'Name': 'Seagate Technology',
#   'Sector': 'Information Technology',
#   'Symbol': 'STX'},
#  {'Name': 'Sealed Air', 'Sector': 'Materials', 'Symbol': 'SEE'},
#  {'Name': 'Sempra Energy', 'Sector': 'Utilities', 'Symbol': 'SRE'},
#  {'Name': 'Sherwin-Williams', 'Sector': 'Materials', 'Symbol': 'SHW'},
#  {'Name': 'Simon Property Group Inc', 'Sector': 'Real Estate', 'Symbol': 'SPG'},
#  {'Name': 'Skyworks Solutions',
#   'Sector': 'Information Technology',
#   'Symbol': 'SWKS'},
#  {'Name': 'SL Green Realty', 'Sector': 'Real Estate', 'Symbol': 'SLG'},
#  {'Name': 'Snap-On Inc.', 'Sector': 'Consumer Discretionary', 'Symbol': 'SNA'},
#  {'Name': 'Southern Co.', 'Sector': 'Utilities', 'Symbol': 'SO'},
#  {'Name': 'Southwest Airlines', 'Sector': 'Industrials', 'Symbol': 'LUV'},
#  {'Name': 'Stanley Black & Decker',
#   'Sector': 'Consumer Discretionary',
#   'Symbol': 'SWK'},
#  {'Name': 'Starbucks Corp.',
#   'Sector': 'Consumer Discretionary',
#   'Symbol': 'SBUX'},
#  {'Name': 'State Street Corp.', 'Sector': 'Financials', 'Symbol': 'STT'},
#  {'Name': 'Stericycle Inc', 'Sector': 'Industrials', 'Symbol': 'SRCL'},
#  {'Name': 'Stryker Corp.', 'Sector': 'Health Care', 'Symbol': 'SYK'},
#  {'Name': 'SunTrust Banks', 'Sector': 'Financials', 'Symbol': 'STI'},
#  {'Name': 'SVB Financial', 'Sector': 'Financials', 'Symbol': 'SIVB'},
#  {'Name': 'Symantec Corp.',
#   'Sector': 'Information Technology',
#   'Symbol': 'SYMC'},
#  {'Name': 'Synchrony Financial', 'Sector': 'Financials', 'Symbol': 'SYF'},
#  {'Name': 'Synopsys Inc.',
#   'Sector': 'Information Technology',
#   'Symbol': 'SNPS'},
#  {'Name': 'Sysco Corp.', 'Sector': 'Consumer Staples', 'Symbol': 'SYY'},
#  {'Name': 'T. Rowe Price Group', 'Sector': 'Financials', 'Symbol': 'TROW'},
#  {'Name': 'Take-Two Interactive',
#   'Sector': 'Information Technology',
#   'Symbol': 'TTWO'},
#  {'Name': 'Tapestry, Inc.',
#   'Sector': 'Consumer Discretionary',
#   'Symbol': 'TPR'},
#  {'Name': 'Target Corp.', 'Sector': 'Consumer Discretionary', 'Symbol': 'TGT'},
#  {'Name': 'TE Connectivity Ltd.',
#   'Sector': 'Information Technology',
#   'Symbol': 'TEL'},
#  {'Name': 'TechnipFMC', 'Sector': 'Energy', 'Symbol': 'FTI'},
#  {'Name': 'Texas Instruments',
#   'Sector': 'Information Technology',
#   'Symbol': 'TXN'},
#  {'Name': 'Textron Inc.', 'Sector': 'Industrials', 'Symbol': 'TXT'},
#  {'Name': 'The Bank of New York Mellon Corp.',
#   'Sector': 'Financials',
#   'Symbol': 'BK'},
#  {'Name': 'The Clorox Company', 'Sector': 'Consumer Staples', 'Symbol': 'CLX'},
#  {'Name': 'The Cooper Companies', 'Sector': 'Health Care', 'Symbol': 'COO'},
#  {'Name': 'The Hershey Company', 'Sector': 'Consumer Staples', 'Symbol': 'HSY'},
#  {'Name': 'The Mosaic Company', 'Sector': 'Materials', 'Symbol': 'MOS'},
#  {'Name': 'The Travelers Companies Inc.',
#   'Sector': 'Financials',
#   'Symbol': 'TRV'},
#  {'Name': 'The Walt Disney Company',
#   'Sector': 'Consumer Discretionary',
#   'Symbol': 'DIS'},
#  {'Name': 'Thermo Fisher Scientific', 'Sector': 'Health Care', 'Symbol': 'TMO'},
#  {'Name': 'Tiffany & Co.', 'Sector': 'Consumer Discretionary', 'Symbol': 'TIF'},
#  {'Name': 'Time Warner Inc.',
#   'Sector': 'Consumer Discretionary',
#   'Symbol': 'TWX'},
#  {'Name': 'TJX Companies Inc.',
#   'Sector': 'Consumer Discretionary',
#   'Symbol': 'TJX'},
#  {'Name': 'Torchmark Corp.', 'Sector': 'Financials', 'Symbol': 'TMK'},
#  {'Name': 'Total System Services',
#   'Sector': 'Information Technology',
#   'Symbol': 'TSS'},
#  {'Name': 'Tractor Supply Company',
#   'Sector': 'Consumer Discretionary',
#   'Symbol': 'TSCO'},
#  {'Name': 'TransDigm Group', 'Sector': 'Industrials', 'Symbol': 'TDG'},
#  {'Name': 'TripAdvisor', 'Sector': 'Consumer Discretionary', 'Symbol': 'TRIP'},
#  {'Name': 'Twenty-First Century Fox Class A',
#   'Sector': 'Consumer Discretionary',
#   'Symbol': 'FOXA'},
#  {'Name': 'Twenty-First Century Fox Class B',
#   'Sector': 'Consumer Discretionary',
#   'Symbol': 'FOX'},
#  {'Name': 'Tyson Foods', 'Sector': 'Consumer Staples', 'Symbol': 'TSN'},
#  {'Name': 'U.S. Bancorp', 'Sector': 'Financials', 'Symbol': 'USB'},
#  {'Name': 'UDR Inc', 'Sector': 'Real Estate', 'Symbol': 'UDR'},
#  {'Name': 'Ulta Beauty', 'Sector': 'Consumer Discretionary', 'Symbol': 'ULTA'},
#  {'Name': 'Under Armour Class A',
#   'Sector': 'Consumer Discretionary',
#   'Symbol': 'UAA'},
#  {'Name': 'Under Armour Class C',
#   'Sector': 'Consumer Discretionary',
#   'Symbol': 'UA'},
#  {'Name': 'Union Pacific', 'Sector': 'Industrials', 'Symbol': 'UNP'},
#  {'Name': 'United Continental Holdings',
#   'Sector': 'Industrials',
#   'Symbol': 'UAL'},
#  {'Name': 'United Health Group Inc.', 'Sector': 'Health Care', 'Symbol': 'UNH'},
#  {'Name': 'United Parcel Service', 'Sector': 'Industrials', 'Symbol': 'UPS'},
#  {'Name': 'United Rentals, Inc.', 'Sector': 'Industrials', 'Symbol': 'URI'},
#  {'Name': 'United Technologies', 'Sector': 'Industrials', 'Symbol': 'UTX'},
#  {'Name': 'Universal Health Services, Inc.',
#   'Sector': 'Health Care',
#   'Symbol': 'UHS'},
#  {'Name': 'Unum Group', 'Sector': 'Financials', 'Symbol': 'UNM'},
#  {'Name': 'V.F. Corp.', 'Sector': 'Consumer Discretionary', 'Symbol': 'VFC'},
#  {'Name': 'Valero Energy', 'Sector': 'Energy', 'Symbol': 'VLO'},
#  {'Name': 'Varian Medical Systems', 'Sector': 'Health Care', 'Symbol': 'VAR'},
#  {'Name': 'Ventas Inc', 'Sector': 'Real Estate', 'Symbol': 'VTR'},
#  {'Name': 'Verisign Inc.',
#   'Sector': 'Information Technology',
#   'Symbol': 'VRSN'},
#  {'Name': 'Verisk Analytics', 'Sector': 'Industrials', 'Symbol': 'VRSK'},
#  {'Name': 'Verizon Communications',
#   'Sector': 'Telecommunication Services',
#   'Symbol': 'VZ'},
#  {'Name': 'Vertex Pharmaceuticals Inc',
#   'Sector': 'Health Care',
#   'Symbol': 'VRTX'},
#  {'Name': 'Viacom Inc.', 'Sector': 'Consumer Discretionary', 'Symbol': 'VIAB'},
#  {'Name': 'Visa Inc.', 'Sector': 'Information Technology', 'Symbol': 'V'},
#  {'Name': 'Vornado Realty Trust', 'Sector': 'Real Estate', 'Symbol': 'VNO'},
#  {'Name': 'Vulcan Materials', 'Sector': 'Materials', 'Symbol': 'VMC'},
#  {'Name': 'Wal-Mart Stores', 'Sector': 'Consumer Staples', 'Symbol': 'WMT'},
#  {'Name': 'Walgreens Boots Alliance',
#   'Sector': 'Consumer Staples',
#   'Symbol': 'WBA'},
#  {'Name': 'Waste Management Inc.', 'Sector': 'Industrials', 'Symbol': 'WM'},
#  {'Name': 'Waters Corporation', 'Sector': 'Health Care', 'Symbol': 'WAT'},
#  {'Name': 'Wec Energy Group Inc', 'Sector': 'Utilities', 'Symbol': 'WEC'},
#  {'Name': 'Wells Fargo', 'Sector': 'Financials', 'Symbol': 'WFC'},
#  {'Name': 'Welltower Inc.', 'Sector': 'Real Estate', 'Symbol': 'WELL'},
#  {'Name': 'Western Digital',
#   'Sector': 'Information Technology',
#   'Symbol': 'WDC'},
#  {'Name': 'Western Union Co',
#   'Sector': 'Information Technology',
#   'Symbol': 'WU'},
#  {'Name': 'WestRock Company', 'Sector': 'Materials', 'Symbol': 'WRK'},
#  {'Name': 'Weyerhaeuser Corp.', 'Sector': 'Real Estate', 'Symbol': 'WY'},
#  {'Name': 'Whirlpool Corp.',
#   'Sector': 'Consumer Discretionary',
#   'Symbol': 'WHR'},
#  {'Name': 'Williams Cos.', 'Sector': 'Energy', 'Symbol': 'WMB'},
#  {'Name': 'Willis Towers Watson', 'Sector': 'Financials', 'Symbol': 'WLTW'},
#  {'Name': 'Wyndham Worldwide',
#   'Sector': 'Consumer Discretionary',
#   'Symbol': 'WYN'},
#  {'Name': 'Wynn Resorts Ltd',
#   'Sector': 'Consumer Discretionary',
#   'Symbol': 'WYNN'},
#  {'Name': 'Xcel Energy Inc', 'Sector': 'Utilities', 'Symbol': 'XEL'},
#  {'Name': 'Xerox Corp.', 'Sector': 'Information Technology', 'Symbol': 'XRX'},
#  {'Name': 'Xilinx Inc', 'Sector': 'Information Technology', 'Symbol': 'XLNX'},
#  {'Name': 'XL Capital', 'Sector': 'Financials', 'Symbol': 'XL'},
#  {'Name': 'Xylem Inc.', 'Sector': 'Industrials', 'Symbol': 'XYL'},
#  {'Name': 'Yum! Brands Inc',
#   'Sector': 'Consumer Discretionary',
#   'Symbol': 'YUM'},
#  {'Name': 'Zimmer Biomet Holdings', 'Sector': 'Health Care', 'Symbol': 'ZBH'},
#  {'Name': 'Zions Bancorp', 'Sector': 'Financials', 'Symbol': 'ZION'},
#  {'Name': 'Zoetis', 'Sector': 'Health Care', 'Symbol': 'ZTS'}]

# %% [markdown]
# We transformed the json into a data frame

# %%
ct = 0
jname = []
jsector = []
jsymbol = []

for x in json_data:
    jname.append(json_data[ct]["Name"])
    jsector.append(json_data[ct]["Sector"])
    jsymbol.append(json_data[ct]["Symbol"])
    ct = ct +1
    
df = pd.DataFrame({
    "Name":jname,
    "Sector":jsector,
    "Symbol":jsymbol
}
)
df.head()
# Out:
#                   Name                  Sector Symbol
# 0           3M Company             Industrials    MMM
# 1      A.O. Smith Corp             Industrials    AOS
# 2  Abbott Laboratories             Health Care    ABT
# 3          AbbVie Inc.             Health Care   ABBV
# 4        Accenture plc  Information Technology    ACN

# %% [markdown]
# We imported a csv file and loaded it into a data frame

# %%
a = pd.read_csv("all_stocks_5yr.csv")

# %%
names = a.Name.unique()

# %% [markdown]
# This code makes the data in the five year data only include stocks from the s&p 500

# %%
list_list = []
open_value_list = []
for x in jsymbol:
    list_list.append(a.loc[a["Name"]==x])

# %% [markdown]
# We are making three lists below in a for loop. These three list will be used in making a data frame.

# %%
percent_list = []
open_list = []
close_list = []
ct = 0
for x in list(range(0,505)):
    
    percent_list.append(100*(list_list[ct].close.mean()-list_list[ct].open.mean())/list_list[ct].open.mean())
    open_list.append(list_list[ct].open.mean())
    close_list.append(list_list[ct].close.mean())
    ct = ct + 1

# %% [markdown]
# This is the second data frame we have. it will be merged later.

# %%
df2 = pd.DataFrame({
    "Name":jname,
    "Symbol":jsymbol,
  
    "2013 Open":open_list,
    "2018 Close":close_list
})
df2
# Out:
#                                     Name Symbol   2013 Open  2018 Close
# 0                             3M Company    MMM  160.199890  160.306330
# 1                        A.O. Smith Corp    AOS   36.439635   36.460653
# 2                    Abbott Laboratories    ABT   42.924758   42.940326
# 3                            AbbVie Inc.   ABBV   60.802801   60.864440
# 4                          Accenture plc    ACN  101.022826  101.119079
# 5                    Activision Blizzard   ATVI   32.728952   32.739281
# 6                      Acuity Brands Inc    AYI  166.818324  166.892184
# 7                      Adobe Systems Inc   ADBE   90.387609   90.458156
# 8                     Advance Auto Parts    AAP  132.439631  132.433463
# 9             Advanced Micro Devices Inc    AMD    5.604315    5.601863
# 10                              AES Corp    AES   12.337340   12.340048
# 11                             Aetna Inc    AET  104.756358  104.821712
# 12         Affiliated Managers Group Inc    AMG  179.206223  179.174662
# 13                             AFLAC Inc    AFL   66.089162   66.122387
# 14              Agilent Technologies Inc      A   49.187863   49.202025
# 15          Air Products & Chemicals Inc    APD  132.591970  132.617697
# 16               Akamai Technologies Inc   AKAM   56.606090   56.625419
# 17                  Alaska Air Group Inc    ALK   61.763858   61.767065
# 18                        Albemarle Corp    ALB   75.366855   75.361783
# 19   Alexandria Real Estate Equities Inc    ARE   91.947065   91.985679
# 20               Alexion Pharmaceuticals   ALXN  142.601724  142.517710
# 21                      Align Technology   ALGN   83.626938   83.664518
# 22                              Allegion   ALLE   64.166778   64.182112
# 23                         Allergan, Plc    AGN  222.401175  222.261033
# 24                 Alliance Data Systems    ADS  241.007335  241.044051
# 25                   Alliant Energy Corp    LNT   32.785743   32.786640
# 26                         Allstate Corp    ALL   67.193684   67.228483
# 27                  Alphabet Inc Class A  GOOGL  682.357041  682.233847
# 28                  Alphabet Inc Class C   GOOG  725.364168  725.403353
# 29                      Altria Group Inc     MO   53.741700   53.769118
# ..                                   ...    ...         ...         ...
# 475           Vertex Pharmaceuticals Inc   VRTX  101.599640  101.611135
# 476                          Viacom Inc.   VIAB   56.601001   56.572192
# 477                            Visa Inc.      V   71.041770   71.051984
# 478                 Vornado Realty Trust    VNO   94.929365   94.935191
# 479                     Vulcan Materials    VMC   89.388141   89.398415
# 480                      Wal-Mart Stores    WMT   75.390997   75.423717
# 481             Walgreens Boots Alliance    WBA   73.066771   73.092002
# 482                Waste Management Inc.     WM   55.955346   55.988173
# 483                   Waters Corporation    WAT  131.254765  131.316835
# 484                 Wec Energy Group Inc    WEC   52.295683   52.323340
# 485                          Wells Fargo    WFC   50.416771   50.429519
# 486                       Welltower Inc.   WELL         NaN         NaN
# 487                      Western Digital    WDC   75.958892   75.954726
# 488                     Western Union Co     WU   18.512014   18.520481
# 489                     WestRock Company    WRK   51.209062   51.198943
# 490                   Weyerhaeuser Corp.     WY   31.485826   31.483157
# 491                      Whirlpool Corp.    WHR  162.105016  162.135203
# 492                        Williams Cos.    WMB   36.595234   36.587585
# 493                 Willis Towers Watson   WLTW  133.875417  133.938201
# 494                    Wyndham Worldwide    WYN   79.024353   79.048674
# 495                     Wynn Resorts Ltd   WYNN  133.376363  133.347144
# 496                      Xcel Energy Inc    XEL   36.763872   36.783658
# 497                          Xerox Corp.    XRX   40.488308   40.486807
# 498                           Xilinx Inc   XLNX   49.819316   49.833474
# 499                           XL Capital     XL   35.302311   35.315099
# 500                           Xylem Inc.    XYL   41.415473   41.434095
# 501                      Yum! Brands Inc    YUM   75.422099   75.451009
# 502               Zimmer Biomet Holdings    ZBH  105.542014  105.606291
# 503                        Zions Bancorp   ZION   32.161477   32.171790
# 504                               Zoetis    ZTS   45.091389   45.098648
#
# [505 rows x 4 columns]

# %% [markdown]
# We are saving our data to a csv file

# %%
df2.to_csv("df2.csv",index=False)

# %% [markdown]
# We are loading a third set of data.

# %%
csv3 = pd.read_csv("wiki.csv")
csv3.head()
# Out:
#   Symbol    Headquarters Location Date first added      Founded
# 0    MMM      St. Paul, Minnesota              NaN         1902
# 1    ABT  North Chicago, Illinois        3/31/1964         1888
# 2   ABBV  North Chicago, Illinois       12/31/2012  2013 (1888)
# 3   ABMD   Danvers, Massachusetts        5/31/2018         1981
# 4    ACN          Dublin, Ireland         7/6/2011         1989

# %% [markdown]
# We are extracting only two columns from this data set.

# %%
csv3 = csv3[["Symbol","Headquarters Location"]]

# %% [markdown]
# our final merge to make the final data frame

# %%
final_df = df2.merge(csv3, on='Symbol',how="inner")

# %%
final_df.head()
# Out:
#                   Name Symbol   2013 Open  2018 Close    Headquarters Location
# 0           3M Company    MMM  160.199890  160.306330      St. Paul, Minnesota
# 1      A.O. Smith Corp    AOS   36.439635   36.460653     Milwaukee, Wisconsin
# 2  Abbott Laboratories    ABT   42.924758   42.940326  North Chicago, Illinois
# 3          AbbVie Inc.   ABBV   60.802801   60.864440  North Chicago, Illinois
# 4        Accenture plc    ACN  101.022826  101.119079          Dublin, Ireland

# %%
aa = final_df.fillna("no")
aa.head()
# Out:
#                   Name Symbol 2013 Open 2018 Close    Headquarters Location
# 0           3M Company    MMM     160.2    160.306      St. Paul, Minnesota
# 1      A.O. Smith Corp    AOS   36.4396    36.4607     Milwaukee, Wisconsin
# 2  Abbott Laboratories    ABT   42.9248    42.9403  North Chicago, Illinois
# 3          AbbVie Inc.   ABBV   60.8028    60.8644  North Chicago, Illinois
# 4        Accenture plc    ACN   101.023    101.119          Dublin, Ireland

# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine

# %% [markdown]
# connecting to postgressql we also created the database, stocks3, in postgres. we right clicked on the server we were using and clicked 'create database'

# %%
connection_string = "postgres:postgres@localhost:5432/stocks3"
engine = create_engine(f'postgresql://{connection_string}')

# %% [markdown]
# Check to see if the connection is working

# %%
engine.table_names()
# Out:
# ['stocks3', 'stock4']

# %% [markdown]
# add our data frame to the pgadmin

# %%
aa.to_sql(name='stock4', con=engine, if_exists='append', index=True)

# %% [markdown]
# check to see if table was added to our postgres database

# %%
engine.table_names()
# Out:
# ['stocks3', 'stock4']

# %% [markdown]
# We are bringing the data back from postgres for accesability to our clients

# %%
#db = create_engine(engine)
result_set = engine.execute("SELECT * From aa")

# %%
result_set

# %% [markdown]
# our data

# %%
for r in result_set:
    print(r)
# Out:
# (0, '3M Company', 'MMM', '0.06644201285820955', 'St. Paul, Minnesota')
# (1, 'A.O. Smith Corp', 'AOS', '0.05768078033893303', 'Milwaukee, Wisconsin')
# (2, 'Abbott Laboratories', 'ABT', '0.036267166155193084', 'North Chicago, Illinois')
# (3, 'AbbVie Inc.', 'ABBV', '0.10137591640870909', 'North Chicago, Illinois')
# (4, 'Accenture plc', 'ACN', '0.09527797397003912', 'Dublin, Ireland')
# (5, 'Activision Blizzard', 'ATVI', '0.031561129211317936', 'Santa Monica, California')
# (6, 'Adobe Systems Inc', 'ADBE', '0.07804961422870862', 'San Jose, California')
# (7, 'Advance Auto Parts', 'AAP', '-0.004656849217225768', 'Raleigh, North Carolina')
# (8, 'Advanced Micro Devices Inc', 'AMD', '-0.04376379151495115', 'Sunnyvale, California')
# (9, 'AES Corp', 'AES', '0.021955601091586494', 'Arlington, Virginia')
# (10, 'Affiliated Managers Group Inc', 'AMG', '-0.01761142104755395', 'West Palm Beach, Florida')
# (11, 'AFLAC Inc', 'AFL', '0.05027266279439194', 'Columbus, Georgia')
# (12, 'Agilent Technologies Inc', 'A', '0.028791722969060442', 'Santa Clara, California')
# (13, 'Air Products & Chemicals Inc', 'APD', '0.019402960308254037', 'Allentown, Pennsylvania')
# (14, 'Akamai Technologies Inc', 'AKAM', '0.03414620625918611', 'Cambridge, Massachusetts')
# (15, 'Alaska Air Group Inc', 'ALK', '0.0051922116568066355', 'Seattle, Washington')
# (16, 'Albemarle Corp', 'ALB', '-0.006729065886575201', 'Charlotte, North Carolina')
# (17, 'Alexandria Real Estate Equities Inc', 'ARE', '0.04199588023136776', 'Pasadena, California')
# (18, 'Alexion Pharmaceuticals', 'ALXN', '-0.05891484341574562', 'Boston, Massachusetts')
# (19, 'Align Technology', 'ALGN', '0.04493793899045851', 'San Jose, California')
# (20, 'Allegion', 'ALLE', '0.023897039823838746', 'Dublin, Ireland')
# (21, 'Allergan, Plc', 'AGN', '-0.06301355687337645', 'Dublin, Ireland')
# (22, 'Alliance Data Systems', 'ADS', '0.015234244763013', 'Plano, Texas')
# (23, 'Alliant Energy Corp', 'LNT', '0.0027375854738613094', 'Madison, Wisconsin')
# (24, 'Allstate Corp', 'ALL', '0.05178916358680215', 'Northfield Township, Illinois')
# (25, 'Alphabet Inc Class A', 'GOOGL', '-0.018054109440078715', 'Mountain View, California')
# (26, 'Alphabet Inc Class C', 'GOOG', '0.005402117637776657', 'Mountain View, California')
# (27, 'Altria Group Inc', 'MO', '0.051018905921843966', 'Richmond, Virginia')
# (28, 'Amazon.com Inc.', 'AMZN', '0.0022148470477801594', 'Seattle, Washington')
# (29, 'Ameren Corp', 'AEE', '0.0629602255618366', 'St. Louis, Missouri')
# (30, 'American Airlines Group', 'AAL', '0.0071809208766859456', 'Fort Worth, Texas')
# (31, 'American Electric Power', 'AEP', '0.04420578380183683', 'Columbus, Ohio')
# (32, 'American Express Co', 'AXP', '0.01331873155427013', 'New York, New York')
# (33, 'American International Group, Inc.', 'AIG', '0.025349001371022518', 'New York, New York')
# (34, 'American Tower Corp A', 'AMT', '0.02216462918482299', 'Boston, Massachusetts')
# (35, 'American Water Works Company Inc', 'AWK', '0.04199579777814082', 'Voorhees, New Jersey')
# (36, 'Ameriprise Financial', 'AMP', '0.02570283289144037', 'Minneapolis, Minnesota')
# (37, 'AmerisourceBergen Corp', 'ABC', '0.032350436576034904', 'Chesterbrook, Pennsylvania')
# (38, 'AMETEK Inc.', 'AME', '0.04758967154627047', 'Berwyn, Pennsylvania')
# (39, 'Amgen Inc.', 'AMGN', '-0.0007345189681314823', 'Thousand Oaks, California')
# (40, 'Amphenol Corp', 'APH', '0.06960204616948111', 'Wallingford, Connecticut')
# (41, 'Anadarko Petroleum Corp', 'APC', '-0.035281490791373445', 'The Woodlands, Texas')
# (42, 'Analog Devices, Inc.', 'ADI', '0.005497523504532074', 'Norwood, Massachusetts')
# (43, 'ANSYS', 'ANSS', '0.06870968595212783', 'Canonsburg, Pennsylvania')
# (44, 'Anthem Inc.', 'ANTM', '0.08767536273605737', 'Indianapolis, Indiana')
# (45, 'Aon plc', 'AON', '0.06383972768346195', 'London,†United Kingdom')
# (46, 'Apache Corporation', 'APA', '-0.046315224248753485', 'Houston, Texas')
# (47, 'Apartment Investment & Management', 'AIV', '0.04215693443421778', 'Denver, Colorado')
# (48, 'Apple Inc.', 'AAPL', '0.010333808360967384', 'Cupertino, California')
# (49, 'Applied Materials Inc.', 'AMAT', '0.0004982932472738993', 'Santa Clara, California')
# (50, 'Aptiv Plc', 'APTV', '-0.06027758143502117', 'Gillingham, Kent,†United Kingdom')
# (51, 'Archer-Daniels-Midland Co', 'ADM', '0.053311902367142', 'Chicago, Illinois')
# (52, 'Arconic Inc.', 'ARNC', '0.006994325742564934', 'New York, New York')
# (53, 'Arthur J. Gallagher & Co.', 'AJG', '0.03082489393270735', 'Itasca, Illinois')
# (54, 'Assurant Inc.', 'AIZ', '0.05385729986690751', 'New York, New York')
# (55, 'AT&T Inc.', 'T', '-0.007256274617780569', 'Dallas, Texas')
# (56, 'Autodesk Inc.', 'ADSK', '0.08646633815781712', 'San Rafael, California')
# (57, 'Automatic Data Processing', 'ADP', '0.05643887599218188', 'Roseland, New Jersey')
# (58, 'AutoZone Inc', 'AZO', '0.005331562392409672', 'Memphis, Tennessee')
# (59, 'AvalonBay Communities, Inc.', 'AVB', '0.007677085717339821', 'Arlington, Virginia[3]')
# (60, 'Avery Dennison Corp', 'AVY', '0.04385671563096957', 'Glendale, California')
# (61, 'Baker Hughes, a GE Company', 'BHGE', '-0.13957383455846029', 'Houston, Texas')
# (62, 'Ball Corp', 'BLL', '0.038771305880446014', 'Broomfield, Colorado')
# (63, 'Bank of America Corp', 'BAC', '-0.013815322131546825', 'Charlotte, North Carolina')
# (64, 'Baxter International Inc.', 'BAX', '0.008936253187682815', 'Deerfield, Illinois')
# (65, 'BB&T Corporation', 'BBT', '0.04209045952301819', 'Winston-Salem, North Carolina')
# (66, 'Becton Dickinson', 'BDX', '0.044124406585500354', 'Franklin Lakes, New Jersey')
# (67, 'Berkshire Hathaway', 'BRK.B', '-0.008250519245314912', 'Omaha, Nebraska')
# (68, 'Best Buy Co. Inc.', 'BBY', '0.10902587811889343', 'Richfield, Minnesota')
# (69, 'Biogen Inc.', 'BIIB', '-0.062210495027336436', 'Cambridge, Massachusetts')
# (70, 'BlackRock', 'BLK', '0.014647053742189926', 'New York, New York')
# (71, 'Block H&R', 'HRB', '0.018747376611564743', 'Kansas City, Missouri')
# (72, 'Boeing Company', 'BA', '0.08613914309587012', 'Chicago, Illinois')
# (73, 'Booking Holdings Inc', 'BKNG', 'no', 'Norwalk, Connecticut')
# (74, 'BorgWarner', 'BWA', '0.021974511236132345', 'Auburn Hills, Michigan')
# (75, 'Boston Properties', 'BXP', '0.010748491817562407', 'Boston, Massachusetts')
# (76, 'Boston Scientific', 'BSX', '0.04733573625368271', 'Marlborough, Massachusetts[4]')
# (77, 'Bristol-Myers Squibb', 'BMY', '0.03030356457519762', 'New York, New York')
# (78, 'Broadcom', 'AVGO', '-0.001905997769484739', 'San Jose, California')
# (79, 'Brown-Forman Corp.', 'BF.B', '0.04245598032102354', 'Louisville, Kentucky')
# (80, 'C. H. Robinson Worldwide', 'CHRW', '0.07361603084862019', 'Eden Prairie, Minnesota')
# (81, 'Cabot Oil & Gas', 'COG', '-0.03735790333009994', 'Houston, Texas')
# (82, 'Cadence Design Systems', 'CDNS', '0.09048074223985562', 'San Jose, California')
# (83, 'Campbell Soup', 'CPB', '0.05668794740068727', 'Camden, New Jersey')
# (84, 'Capital One Financial', 'COF', '0.01761707436081553', 'Tysons Corner, Virginia')
# (85, 'Cardinal Health Inc.', 'CAH', '0.03958022979607641', 'Dublin, Ohio')
# (86, 'Carmax Inc', 'KMX', '0.02476064067189427', 'Richmond, Virginia')
# (87, 'Carnival Corp.', 'CCL', '0.005006424911990947', 'Miami, Florida')
# (88, 'Caterpillar Inc.', 'CAT', '0.02010480269390003', 'Deerfield, Illinois')
# (89, 'Cboe Global Markets', 'CBOE', '0.07507189963167378', 'Chicago, Illinois')
# (90, 'CBRE Group', 'CBRE', 'no', 'Los Angeles, California')
# (91, 'CBS Corp.', 'CBS', '-0.02534110000476116', 'New York, New York')
# (92, 'Celgene Corp.', 'CELG', '-0.006120274818543892', 'Summit, New Jersey')
# (93, 'Centene Corporation', 'CNC', '0.04661121642578015', 'St Louis, Missouri')
# (94, 'CenterPoint Energy', 'CNP', '0.036861548697897255', 'Houston, Texas')
# (95, 'CenturyLink Inc', 'CTL', '-0.0619991506252061', 'Monroe, Louisiana')
# (96, 'Cerner', 'CERN', '0.03617904501057599', 'North Kansas City, Missouri')
# (97, 'CF Industries Holdings Inc', 'CF', '-0.01652000894040693', 'Deerfield, Illinois')
# (98, 'Charles Schwab Corporation', 'SCHW', '0.05193101391630082', 'San Francisco, California')
# (99, 'Charter Communications', 'CHTR', '0.04752824351060083', 'Stamford, Connecticut')
# (100, 'Chevron Corp.', 'CVX', '0.009034411136693376', 'San Ramon, California')
# (101, 'Chipotle Mexican Grill', 'CMG', '-0.01540335407227189', 'Newport Beach, California')
# (102, 'Chubb Limited', 'CB', '0.02904932242877401', 'Zurich, Switzerland')
# (103, 'Church & Dwight', 'CHD', '0.04309634586678204', 'Ewing, New Jersey')
# (104, 'CIGNA Corp.', 'CI', '0.07009319347202175', 'Bloomfield, Connecticut')
# (105, 'Cimarex Energy', 'XEC', '0.013219682166003777', 'Denver, Colorado')
# (106, 'Cincinnati Financial', 'CINF', '0.012025919566738437', 'Fairfield, Ohio')
# (107, 'Cintas Corporation', 'CTAS', '0.03910211820826973', 'Mason, Ohio')
# (108, 'Cisco Systems', 'CSCO', '0.06727787718531512', 'San Jose, California')
# (109, 'Citigroup Inc.', 'C', '0.00667046392852446', 'New York, New York')
# (110, 'Citizens Financial Group', 'CFG', '0.033122759440330454', 'Providence, Rhode Island')
# (111, 'Citrix Systems', 'CTXS', '0.02574468009896217', 'Fort Lauderdale, Florida')
# (112, 'CME Group Inc.', 'CME', '0.05889519784218844', 'Chicago, Illinois')
# (113, 'CMS Energy', 'CMS', '0.05638741008978663', 'Jackson, Michigan')
# (114, 'Coca-Cola Company (The)', 'KO', '0.042889448092052085', 'Atlanta, Georgia')
# (115, 'Cognizant Technology Solutions', 'CTSH', '0.015208851980654754', 'Teaneck, New Jersey')
# (116, 'Colgate-Palmolive', 'CL', '0.0348202858596892', 'New York, New York')
# (117, 'Comcast Corp.', 'CMCSA', '0.02445434606897262', 'Philadelphia, Pennsylvania')
# (118, 'Comerica Inc.', 'CMA', '0.05109617245455919', 'Dallas, Texas')
# (119, 'Conagra Brands', 'CAG', '0.040445888042090844', 'Chicago, Illinois')
# (120, 'Concho Resources', 'CXO', '0.017790860443688897', 'Midland, Texas')
# (121, 'ConocoPhillips', 'COP', '-0.010176798442233266', 'Houston, Texas')
# (122, 'Consolidated Edison', 'ED', '0.049526038940022846', 'New York, New York')
# (123, 'Constellation Brands', 'STZ', '0.027878371385454116', 'Victor, New York')
# (124, 'Corning Inc.', 'GLW', '0.08250305671147373', 'Corning, New York')
# (125, 'Costco Wholesale Corp.', 'COST', '0.022628364157749763', 'Issaquah, Washington')
# (126, 'Coty, Inc', 'COTY', '0.008633447941341774', 'New York, New York')
# (127, 'Crown Castle International Corp.', 'CCI', '0.015489015105774084', 'Houston, Texas')
# (128, 'CSX Corp.', 'CSX', '0.08868167145951862', 'Jacksonville, Florida')
# (129, 'Cummins Inc.', 'CMI', '0.022099885641728583', 'Columbus, Indiana')
# (130, 'CVS Health', 'CVS', '0.014679392335614189', 'Woonsocket, Rhode Island')
# (131, 'D. R. Horton', 'DHI', '-0.004541751302391319', 'Fort Worth, Texas')
# (132, 'Danaher Corp.', 'DHR', '0.03503710736102613', 'Washington, D.C.')
# (133, 'Darden Restaurants', 'DRI', '0.03445223535474917', 'Orlando, Florida')
# (134, 'DaVita Inc.', 'DVA', '0.012107752224045889', 'Denver, Colorado')
# (135, 'Deere & Co.', 'DE', '0.058626688247437664', 'Moline, Illinois')
# (136, 'Delta Air Lines Inc.', 'DAL', '-0.034139946918494944', 'Atlanta, Georgia')
# (137, 'Dentsply Sirona', 'XRAY', '0.05015238731520981', 'York, Pennsylvania')
# (138, 'Devon Energy Corp.', 'DVN', '-0.07486168181760022', 'Oklahoma City, Oklahoma')
# (139, 'Digital Realty Trust Inc', 'DLR', '0.032981086928475935', 'San Francisco, California')
# (140, 'Discover Financial Services', 'DFS', '0.028186610702510728', 'Riverwoods, Illinois')
# (141, 'Discovery Inc. Class A', 'DISCA', '-0.015874434697205748', 'Silver Spring, Maryland')
# (142, 'Discovery Inc. Class C', 'DISCK', '0.011728501644923646', 'Silver Spring, Maryland')
# (143, 'Dish Network', 'DISH', '-0.03261704283515899', 'Meridian, Colorado')
# (144, 'Dollar General', 'DG', '0.025963713027919104', 'Goodlettsville, Tennessee')
# (145, 'Dollar Tree', 'DLTR', '0.021383848649348162', 'Chesapeake, Virginia')
# (146, 'Dominion Energy', 'D', '0.03687934352974215', 'Richmond, Virginia')
# (147, 'Dover Corp.', 'DOV', '0.0442308129968454', 'Downers Grove, Illinois')
# (148, 'DTE Energy Co.', 'DTE', '0.035089594981994904', 'Detroit, Michigan')
# (149, 'Duke Energy', 'DUK', '0.022494605315062165', 'Charlotte, North Carolina')
# (150, 'Duke Realty Corp', 'DRE', '0.03567711984024668', 'Indianapolis, Indiana')
# (151, 'DXC Technology', 'DXC', '0.052339987344151524', 'Tysons Corner, Virginia')
# (152, 'E*Trade', 'ETFC', '0.058601981123124605', 'New York, New York')
# (153, 'Eastman Chemical', 'EMN', '0.013016111704953396', 'Kingsport, Tennessee')
# (154, 'Eaton Corporation', 'ETN', '0.02739765043611449', 'Dublin, Ireland')
# (155, 'eBay Inc.', 'EBAY', '0.02402338248368907', 'San Jose, California')
# (156, 'Ecolab Inc.', 'ECL', '0.03934143511591146', 'St. Paul, Minnesota')
# (157, "Edison Int'l", 'EIX', '0.039292558288179756', 'Rosemead, California')
# (158, 'Edwards Lifesciences', 'EW', '0.004964310462674927', 'Irvine, California')
# (159, 'Electronic Arts', 'EA', '0.07660365304615735', 'Redwood City, California')
# (160, 'Emerson Electric Company', 'EMR', '0.021997150516682124', 'Ferguson, Missouri')
# (161, 'Entergy Corp.', 'ETR', '0.028713164332802986', 'New Orleans, Louisiana')
# (162, 'EOG Resources', 'EOG', '-0.0050060899938652505', 'Houston, Texas')
# (163, 'Equifax Inc.', 'EFX', '0.06060206257392465', 'Atlanta, Georgia')
# (164, 'Equinix', 'EQIX', '0.0415369963617482', 'Redwood City, California')
# (165, 'Equity Residential', 'EQR', '0.0082816452821715', 'Chicago, Illinois')
# (166, 'Essex Property Trust, Inc.', 'ESS', '0.015410884214724047', 'Palo Alto, California')
# (167, 'Estee Lauder Cos.', 'EL', '0.037901095304370615', 'New York, New York')
# (168, 'Everest Re Group Ltd.', 'RE', '0.019135152356388675', 'Hamilton, Bermuda')
# (169, 'Eversource Energy', 'ES', '0.05256181135035825', 'Springfield, Massachusetts')
# (170, 'Exelon Corp.', 'EXC', '0.04156122506400291', 'Chicago, Illinois')
# (171, 'Expedia Inc.', 'EXPE', '0.0018942988525644637', 'Bellevue, Washington')
# (172, 'Expeditors International', 'EXPD', '0.07346796306649125', 'Seattle, Washington')
# (173, 'Extra Space Storage', 'EXR', '0.01899862137904256', 'Salt Lake City, Utah')
# (174, 'Exxon Mobil Corp.', 'XOM', '0.018082614031043016', 'Irving, Texas')
# (175, 'F5 Networks', 'FFIV', '0.046776505994916374', 'Seattle, Washington')
# (176, 'Facebook, Inc.', 'FB', '0.02441654488046043', 'Menlo Park, California')
# (177, 'Fastenal Co', 'FAST', '0.016174788150584957', 'Winona, Minnesota')
# (178, 'Federal Realty Investment Trust', 'FRT', '-0.009193206964795466', 'Rockville, Maryland')
# (179, 'FedEx Corporation', 'FDX', '0.039032588769987636', 'Memphis, Tennessee')
# (180, 'Fidelity National Information Services', 'FIS', '0.07658111205994593', 'Jacksonville, Florida')
# (181, 'Fifth Third Bancorp', 'FITB', '0.02351609873702842', 'Cincinnati, Ohio')
# (182, 'FirstEnergy Corp', 'FE', '0.006298870192633938', 'Akron, Ohio')
# (183, 'Fiserv Inc', 'FISV', '0.1002065999147864', 'Brookfield, Wisconsin')
# (184, 'FLIR Systems', 'FLIR', '0.05218748375850719', 'Wilsonville, Oregon')
# (185, 'Flowserve Corporation', 'FLS', '0.008228660553696596', 'Irving, Texas')
# (186, 'FMC Corporation', 'FMC', '-0.014960129299607253', 'Philadelphia, Pennsylvania')
# (187, 'Foot Locker Inc', 'FL', '0.0005552156402312708', 'New York, New York')
# (188, 'Ford Motor', 'F', '-0.07108232083320602', 'Dearborn, Michigan')
# (189, 'Fortive Corp', 'FTV', '0.0033597676946900885', 'Everett, Washington')
# (190, 'Fortune Brands Home & Security', 'FBHS', '0.05661990145001951', 'Deerfield, Illinois')
# (191, 'Franklin Resources', 'BEN', '-0.01808343255108369', 'San Mateo, California')
# (192, 'Freeport-McMoRan Inc.', 'FCX', '-0.08979890596043215', 'Phoenix, Arizona')
# (193, 'Gap Inc.', 'GPS', '0.01949120919639513', 'San Francisco, California')
# (194, 'Garmin Ltd.', 'GRMN', '0.022588700490702013', 'Schaffhausen, Switzerland')
# (195, 'Gartner Inc', 'IT', '0.0611329024169154', 'Stamford, Connecticut')
# (196, 'General Dynamics', 'GD', '0.08110762406530107', 'Falls Church, Virginia')
# (197, 'General Electric', 'GE', '-0.010736147216674301', 'Boston, Massachusetts')
# (198, 'General Mills', 'GIS', '0.051089913998423345', 'Golden Valley, Minnesota')
# (199, 'General Motors', 'GM', '-0.04872090115170544', 'Detroit, Michigan')
# (200, 'Genuine Parts', 'GPC', '0.02740008052160478', 'Atlanta, Georgia')
# (201, 'Gilead Sciences', 'GILD', '-0.06775757492181665', 'Foster City, California')
# (202, 'Global Payments Inc.', 'GPN', '0.056795905061963185', 'Atlanta, Georgia')
# (203, 'Goldman Sachs Group', 'GS', '0.019788087037822057', 'New York, New York')
# (204, 'Grainger (W.W.) Inc.', 'GWW', '0.023792641526483867', 'Lake Forest, Illinois')
# (205, 'Halliburton Co.', 'HAL', '0.0025213215159065492', 'Houston, Texas')
# (206, 'Hanesbrands Inc', 'HBI', '-0.006121687656353302', 'Winston-Salem, North Carolina')
# (207, 'Harley-Davidson', 'HOG', '0.029935080699792664', 'Milwaukee, Wisconsin')
# (208, 'Hartford Financial Svc.Gp.', 'HIG', '0.059411204157097', 'Hartford, Connecticut')
# (209, 'Hasbro Inc.', 'HAS', '0.042547029359453495', 'Pawtucket, Rhode Island')
# (210, 'HCA Holdings', 'HCA', '0.08427535672408937', 'Nashville, Tennessee')
# (211, 'HCP Inc.', 'HCP', '-0.043106580012909054', 'Long Beach, California')
# (212, 'Helmerich & Payne', 'HP', '0.0026287799132771674', 'Tulsa, Oklahoma[5]')
# (213, 'Henry Schein', 'HSIC', '0.013038149329440665', 'Melville, New York')
# (214, 'Hess Corporation', 'HES', '-0.011148963901308716', 'New York, New York')
# (215, 'Hewlett Packard Enterprise', 'HPE', '0.185596889523511', 'Palo Alto, California')
# (216, 'Hilton Worldwide Holdings Inc', 'HLT', '0.03380816911412283', 'Tysons Corner, Virginia')
# (217, 'Hologic', 'HOLX', '0.031790890953570475', 'Marlborough, Massachusetts')
# (218, 'Home Depot', 'HD', '0.038190600912197205', 'Atlanta, Georgia')
# (219, "Honeywell Int'l Inc.", 'HON', '0.024441149761439983', 'Morristown, New Jersey')
# (220, 'Hormel Foods Corp.', 'HRL', '0.024259451235105704', 'Austin, Minnesota')
# (221, 'Host Hotels & Resorts', 'HST', '0.011290411481526975', 'Bethesda, Maryland')
# (222, 'HP Inc.', 'HPQ', '0.16129643551362668', 'Palo Alto, California')
# (223, 'Humana Inc.', 'HUM', '0.09182423927487121', 'Louisville, Kentucky')
# (224, 'Huntington Bancshares', 'HBAN', '0.023373157759377382', 'Columbus, Ohio')
# (225, 'Huntington Ingalls Industries', 'HII', '0.06961322556832875', 'Newport News, Virginia')
# (226, 'IDEXX Laboratories', 'IDXX', '0.06351272091886634', 'Westbrook, Maine')
# (227, 'IHS Markit Ltd.', 'INFO', '0.12097733812747083', 'London,†United Kingdom')
# (228, 'Illinois Tool Works', 'ITW', '0.05783694264665019', 'Glenview, Illinois')
# (229, 'Illumina Inc', 'ILMN', '0.04710895482096925', 'San Diego, California')
# (230, 'Incyte', 'INCY', '-0.007121875737779169', 'Wilmington, Delaware')
# (231, 'Ingersoll-Rand PLC', 'IR', '0.0363897919298809', 'Dublin, Ireland')
# (232, 'Intel Corp.', 'INTC', '0.08488881601968078', 'Santa Clara, California')
# (233, 'Intercontinental Exchange', 'ICE', '0.031919129548868636', 'Atlanta, Georgia')
# (234, 'International Business Machines', 'IBM', '0.018570399530761336', 'Armonk, New York')
# (235, 'International Paper', 'IP', '0.007669072755786728', 'Memphis, Tennessee')
# (236, 'Interpublic Group', 'IPG', '0.03834025677645703', 'New York, New York')
# (237, 'Intl Flavors & Fragrances', 'IFF', '0.03728582106536564', 'New York, New York')
# (238, 'Intuit Inc.', 'INTU', '0.09887692511822735', 'Mountain View, California')
# (239, 'Intuitive Surgical Inc.', 'ISRG', '0.042913913306302946', 'Sunnyvale, California')
# (240, 'Invesco Ltd.', 'IVZ', '-0.04114923949791576', 'Atlanta, Georgia')
# (241, 'IPG Photonics Corp.', 'IPGP', 'no', 'Oxford, Massachusetts')
# (242, 'IQVIA Holdings Inc.', 'IQV', '0.04435255200971656', 'Durham, North Carolina')
# (243, 'Iron Mountain Incorporated', 'IRM', '0.01262033640879392', 'Boston, Massachusetts')
# (244, 'J. B. Hunt Transport Services', 'JBHT', '0.03612249644724795', 'Lowell, Arkansas')
# (245, 'Jacobs Engineering Group', 'JEC', '0.035847261328829615', 'Pasadena, California')
# (246, 'JM Smucker', 'SJM', '0.040426540339854905', 'Orrville, Ohio')
# (247, 'Johnson & Johnson', 'JNJ', '0.025490533188528057', 'New Brunswick, New Jersey')
# (248, 'Johnson Controls International', 'JCI', '0.04250057862311604', 'Cork, Ireland')
# (249, 'JPMorgan Chase & Co.', 'JPM', '0.038084041200908976', 'New York, New York')
# (250, 'Juniper Networks', 'JNPR', '0.06730215650890131', 'Sunnyvale, California')
# (251, 'Kansas City Southern', 'KSU', '0.017799669789777796', 'Kansas City, Missouri')
# (252, 'Kellogg Co.', 'K', '0.027274576531322762', 'Battle Creek, Michigan')
# (253, 'KeyCorp', 'KEY', '0.02306085010193117', 'Cleveland, Ohio')
# (254, 'Kimberly-Clark', 'KMB', '0.038361449814034256', 'Irving, Texas')
# (255, 'Kimco Realty', 'KIM', '-0.03607637152471643', 'New Hyde Park, New York')
# (256, 'Kinder Morgan', 'KMI', '-0.0825085617172212', 'Houston, Texas')
# (257, 'KLA-Tencor Corp.', 'KLAC', '0.03835884226326425', 'Milpitas, California')
# (258, "Kohl's Corp.", 'KSS', '0.048845021690514794', 'Menomonee Falls, Wisconsin')
# (259, 'Kraft Heinz Co', 'KHC', '-0.02799938203393674', 'Chicago, Illinois;†Pittsburgh, Pennsylvania')
# (260, 'Kroger Co.', 'KR', '0.043262828725323776', 'Cincinnati, Ohio')
# (261, 'L Brands Inc.', 'LB', '0.03600491776235975', 'Columbus, Ohio')
# (262, 'Laboratory Corp. of America Holding', 'LH', '0.04330627026133984', 'Burlington, North Carolina')
# (263, 'Lam Research', 'LRCX', '-0.013644885901510608', 'Fremont, California')
# (264, 'Leggett & Platt', 'LEG', '0.02470016170045482', 'Carthage, Missouri')
# (265, 'Lennar Corp.', 'LEN', '-0.037845939353147125', 'Miami, Florida')
# (266, 'Lilly (Eli) & Co.', 'LLY', '0.026394803333689123', 'Indianapolis, Indiana')
# (267, 'Lincoln National', 'LNC', '0.04040264778111411', 'Radnor, Pennsylvania')
# (268, 'LKQ Corporation', 'LKQ', '0.01107755928315132', 'Chicago, Illinois')
# (269, 'Lockheed Martin Corp.', 'LMT', '0.05660788209712971', 'Bethesda, Maryland')
# (270, 'Loews Corp.', 'L', '-0.0026990907042989463', 'New York, New York')
# (271, "Lowe's Cos.", 'LOW', '0.04780658049066255', 'Mooresville, North Carolina')
# (272, 'LyondellBasell', 'LYB', '-0.0017896928689481184', 'Rotterdam, Netherlands')
# (273, 'M&T Bank Corp.', 'MTB', '0.045606146312888174', 'Buffalo, New York')
# (274, 'Macerich', 'MAC', '0.016735316781657527', 'Santa Monica, California')
# (275, "Macy's Inc.", 'M', '-0.0327113217838294', 'Cincinnati, Ohio')
# (276, 'Marathon Oil Corp.', 'MRO', '-0.08044474226701853', 'Houston, Texas')
# (277, 'Marathon Petroleum', 'MPC', '0.014087425867174508', 'Findlay, Ohio')
# (278, "Marriott Int'l.", 'MAR', '0.09733013237965821', 'Bethesda, Maryland')
# (279, 'Marsh & McLennan', 'MMC', '0.06803841915340807', 'New York, New York')
# (280, 'Martin Marietta Materials', 'MLM', '0.020423988023485783', 'Raleigh, North Carolina')
# (281, 'Masco Corp.', 'MAS', '0.018699953513468138', 'Taylor, Michigan')
# (282, 'Mastercard Inc.', 'MA', '0.03349189566374299', 'Harrison, New York')
# (283, 'McCormick & Co.', 'MKC', '0.04305175782817338', 'Sparks, Maryland')
# (284, "McDonald's Corp.", 'MCD', '0.04471924097329577', 'Chicago, Illinois')
# (285, 'McKesson Corp.', 'MCK', '0.011674177862951845', 'San Francisco, California')
# (286, 'Medtronic plc', 'MDT', '0.03687465901613004', 'Dublin,†Ireland')
# (287, 'Merck & Co.', 'MRK', '-0.015319993789886606', 'Whitehouse Station, New Jersey')
# (288, 'MetLife Inc.', 'MET', '0.009602748664778574', 'New York, New York')
# (289, 'Mettler Toledo', 'MTD', '0.05522929111248938', 'Columbus, Ohio')
# (290, 'MGM Resorts International', 'MGM', '-0.003827338903059298', 'Paradise, Nevada')
# (291, 'Microchip Technology', 'MCHP', '0.014316736522757386', 'Chandler, Arizona')
# (292, 'Micron Technology', 'MU', '-0.057807011611908606', 'Boise, Idaho')
# (293, 'Microsoft Corp.', 'MSFT', '0.07189678769309671', 'Redmond, Washington')
# (294, 'Mid-America Apartments', 'MAA', '0.02225760317247471', 'Memphis, Tennessee')
# (295, 'Mohawk Industries', 'MHK', '0.002577976966887749', 'Amsterdam, New York')
# (296, 'Molson Coors Brewing Company', 'TAP', '-0.0013568778593156833', 'Denver, Colorado')
# (297, 'Mondelez International', 'MDLZ', '0.0013312326279071775', 'Deerfield, Illinois')
# (298, 'Monster Beverage', 'MNST', '0.02754762181806218', 'Corona, California')
# (299, "Moody's Corp", 'MCO', '0.07980901265547814', 'New York, New York')
# (300, 'Morgan Stanley', 'MS', '0.006950729859675441', 'New York, New York')
# (301, 'Motorola Solutions Inc.', 'MSI', '0.050308181349656124', 'Schaumburg, Illinois')
# (302, 'Mylan N.V.', 'MYL', '-0.04888921122066442', 'Amsterdam,†Netherlands')
# (303, 'Nasdaq, Inc.', 'NDAQ', '0.07395547083424923', 'New York, New York')
# (304, 'National Oilwell Varco Inc.', 'NOV', '-0.009453063409038513', 'Houston, Texas')
# (305, 'Nektar Therapeutics', 'NKTR', 'no', 'San Francisco, California')
# (306, 'NetApp', 'NTAP', '0.08889573533922307', 'Sunnyvale, California')
# (307, 'Netflix Inc.', 'NFLX', '0.05494726671153885', 'Los Gatos, California')
# (308, 'Newell Brands', 'NWL', '0.016481395183065226', 'Hoboken, New Jersey')
# (309, 'Newmont Mining Corporation', 'NEM', '-0.060920849737342554', 'Denver, Colorado')
# (310, 'News Corp. Class A', 'NWSA', '0.01385439800997977', 'New York, New York')
# (311, 'News Corp. Class B', 'NWS', '0.01775030239114605', 'New York, New York')
# (312, 'NextEra Energy', 'NEE', '0.05995858020781397', 'Juno Beach, Florida')
# (313, 'Nielsen Holdings', 'NLSN', '0.053755579357574634', 'New York, New York')
# (314, 'Nike', 'NKE', '0.03284579214959302', 'Washington County, Oregon')
# (315, 'NiSource Inc.', 'NI', '0.07439579063540731', 'Merrillville, Indiana')
# (316, 'Noble Energy Inc', 'NBL', '-0.028611972198899396', 'Houston, Texas')
# (317, 'Nordstrom', 'JWN', '0.031878656047446566', 'Seattle, Washington')
# (318, 'Norfolk Southern Corp.', 'NSC', '0.0757104117982587', 'Norfolk, Virginia')
# (319, 'Northern Trust Corp.', 'NTRS', '0.041583333499427215', 'Chicago, Illinois')
# (320, 'Northrop Grumman Corp.', 'NOC', '0.07348523344026053', 'West Falls Church, Virginia')
# (321, 'Norwegian Cruise Line', 'NCLH', '0.014253687988701896', 'Miami, Florida')
# (322, 'NRG Energy', 'NRG', '-0.02435888354703761', 'Princeton, New Jersey')
# (323, 'Nucor Corp.', 'NUE', '0.000822587017356998', 'Charlotte, North Carolina')
# (324, 'Nvidia Corporation', 'NVDA', '0.09379566436073575', 'Santa Clara, California')
# (325, "O'Reilly Automotive", 'ORLY', '0.038101239503159426', 'Springfield, Missouri')
# (326, 'Occidental Petroleum', 'OXY', '-0.010178438380039815', 'Houston, Texas')
# (327, 'Omnicom Group', 'OMC', '0.004835554306694861', 'New York, New York')
# (328, 'ONEOK', 'OKE', '0.019218942808381094', 'Tulsa, Oklahoma')
# (329, 'Oracle Corp.', 'ORCL', '0.043840084961504044', 'Redwood Shores, California')
# (330, 'PACCAR Inc.', 'PCAR', '0.03924367264640061', 'Bellevue, Washington')
# (331, 'Packaging Corporation of America', 'PKG', '0.012431081247276078', 'Lake Forest, Illinois')
# (332, 'Parker-Hannifin', 'PH', '0.04078459229074421', 'Cleveland, Ohio')
# (333, 'Paychex Inc.', 'PAYX', '0.062083607352083854', 'Penfield, New York')
# (334, 'PayPal', 'PYPL', '-0.018516249910511713', 'San Jose, California')
# (335, 'Pentair Ltd.', 'PNR', '0.017729432236816636', 'Worsley, UK')
# (336, "People's United Financial", 'PBCT', '0.0273483229884898', 'Bridgeport, Connecticut')
# (337, 'PepsiCo Inc.', 'PEP', '0.04765602427605247', 'Purchase, New York')
# (338, 'PerkinElmer', 'PKI', '0.06791267651844804', 'Waltham, Massachusetts')
# (339, 'Perrigo', 'PRGO', '-0.023963123226558036', 'Dublin, Ireland')
# (340, 'Pfizer Inc.', 'PFE', '0.0063626193843070965', 'New York, New York')
# (341, 'Philip Morris International', 'PM', '0.0378718766141204', 'New York, New York')
# (342, 'Phillips 66', 'PSX', '0.02620880880095346', 'Houston, Texas')
# (343, 'Pinnacle West Capital', 'PNW', '0.04288883464324499', 'Phoenix, Arizona')
# (344, 'Pioneer Natural Resources', 'PXD', '0.02466231331238617', 'Irving, Texas')
# (345, 'PNC Financial Services', 'PNC', '0.04241967510625054', 'Pittsburgh, Pennsylvania')
# (346, 'Polo Ralph Lauren Corp.', 'RL', '-0.028109586647619183', 'New York, New York')
# (347, 'PPG Industries', 'PPG', '0.03344750525857535', 'Pittsburgh, Pennsylvania')
# (348, 'PPL Corp.', 'PPL', '0.015186740273738309', 'Allentown, Pennsylvania')
# (349, 'Principal Financial Group', 'PFG', '0.042588428477610484', 'Des Moines, Iowa')
# (350, 'Procter & Gamble', 'PG', '0.01022207337227227', 'Cincinnati, Ohio')
# (351, 'Progressive Corp.', 'PGR', '0.05173535517253113', 'Mayfield Village, Ohio')
# (352, 'Prologis', 'PLD', '0.01850281103392836', 'San Francisco, California')
# (353, 'Prudential Financial', 'PRU', '0.029601401904199836', 'Newark, New Jersey')
# (354, 'Public Serv. Enterprise Inc.', 'PEG', '0.043102006844302536', 'Newark, New Jersey')
# (355, 'Public Storage', 'PSA', '0.01851839956926232', 'Glendale, California')
# (356, 'Pulte Homes Inc.', 'PHM', '-0.008088334146554927', 'Atlanta, Georgia')
# (357, 'PVH Corp.', 'PVH', '-0.04487083578964989', 'New York, New York')
# (358, 'Qorvo', 'QRVO', '0.04645608428016665', 'Greensboro, North Carolina')
# (359, 'QUALCOMM Inc.', 'QCOM', '0.02821084945794921', 'San Diego, California')
# (360, 'Quanta Services Inc.', 'PWR', '-0.030566535764910717', 'Houston, Texas')
# (361, 'Quest Diagnostics', 'DGX', '0.0495848710332979', 'Madison, New Jersey')
# (362, 'Raymond James Financial Inc.', 'RJF', '0.028391467872734683', 'St. Petersburg, Florida')
# (363, 'Raytheon Co.', 'RTN', '0.04163749629903187', 'Waltham, Massachusetts')
# (364, 'Realty Income Corporation', 'O', '-0.0017113562771704522', 'San Diego, California')
# (365, 'Regency Centers Corporation', 'REG', '0.0076062960797767636', 'Jacksonville, Florida')
# (366, 'Regeneron', 'REGN', '-0.007441143851846103', 'Tarrytown, New York')
# (367, 'Regions Financial Corp.', 'RF', '0.029024403057523133', 'Birmingham, Alabama')
# (368, 'Republic Services Inc', 'RSG', '0.05766950828307186', 'Phoenix, Arizona')
# (369, 'ResMed', 'RMD', '0.11017515617727723', 'San Diego, California')
# (370, 'Robert Half International', 'RHI', '0.05904465236794514', 'Menlo Park, California')
# (371, 'Rockwell Automation Inc.', 'ROK', '0.029203798150081912', 'Milwaukee, Wisconsin')
# (372, 'Roper Technologies', 'ROP', '0.0704427689632553', 'Sarasota, Florida')
# (373, 'Ross Stores', 'ROST', '0.013329376590789093', 'Pleasanton, California')
# (374, 'Royal Caribbean Cruises Ltd', 'RCL', '0.06917190984522247', 'Miami, Florida')
# (375, 'S&P Global, Inc.', 'SPGI', '0.06983971140404412', 'New York, New York')
# (376, 'Salesforce.com', 'CRM', '0.03261159139603462', 'San Francisco, California')
# (377, 'SBA Communications', 'SBAC', '0.04613780497059094', 'Boca Raton, Florida')
# (378, 'Schlumberger Ltd.', 'SLB', '0.0019782419549484744', 'CuraÁao,†Kingdom of the Netherlands')
# (379, 'Seagate Technology', 'STX', '0.02177161950153154', 'Dublin, Ireland')
# (380, 'Sealed Air', 'SEE', '0.01082904403583142', 'Elmwood Park, New Jersey')
# (381, 'Sempra Energy', 'SRE', '0.0401587659012162', 'San Diego, California')
# (382, 'Sherwin-Williams', 'SHW', '0.0688696210276894', 'Cleveland, Ohio')
# (383, 'Simon Property Group Inc', 'SPG', '-0.026030990844763725', 'Indianapolis, Indiana')
# (384, 'Skyworks Solutions', 'SWKS', '0.004454718094243159', 'Woburn, Massachusetts')
# (385, 'SL Green Realty', 'SLG', '-0.0021616298096377336', 'New York, New York')
# (386, 'Snap-On Inc.', 'SNA', '0.02233256274439734', 'Kenosha, Wisconsin')
# (387, 'Southern Co.', 'SO', '0.028460453683411803', 'Atlanta, Georgia')
# (388, 'Southwest Airlines', 'LUV', '0.024351458541504084', 'Dallas, Texas')
# (389, 'Stanley Black & Decker', 'SWK', '0.014769222295397975', 'New Britain, Connecticut')
# (390, 'Starbucks Corp.', 'SBUX', '0.016444135260535942', 'Seattle, Washington')
# (391, 'State Street Corp.', 'STT', '0.06312497095227644', 'Boston, Massachusetts')
# (392, 'Stryker Corp.', 'SYK', '0.04811824312915449', 'Kalamazoo, Michigan')
# (393, 'SunTrust Banks', 'STI', '0.022960461791374457', 'Atlanta, Georgia')
# (394, 'SVB Financial', 'SIVB', 'no', 'Santa Clara, California')
# (395, 'Symantec Corp.', 'SYMC', '0.08206968658657827', 'Mountain View, California')
# (396, 'Synchrony Financial', 'SYF', '-0.0333970686622989', 'Stamford, Connecticut')
# (397, 'Synopsys Inc.', 'SNPS', '0.06836274763888518', 'Mountain View, California')
# (398, 'Sysco Corp.', 'SYY', '0.03631826159293636', 'Houston, Texas')
# (399, 'T. Rowe Price Group', 'TROW', '0.0018907323841049733', 'Baltimore, Maryland')
# (400, 'Take-Two Interactive', 'TTWO', 'no', 'New York, New York')
# (401, 'Tapestry, Inc.', 'TPR', '0.012113810485639193', 'New York, New York')
# (402, 'Target Corp.', 'TGT', '0.017922796306303855', 'Minneapolis, Minnesota')
# (403, 'TE Connectivity Ltd.', 'TEL', '0.03004357724770708', 'Schaffhausen, Switzerland')
# (404, 'TechnipFMC', 'FTI', '-0.01926642184798525', 'London,†United Kingdom')
# (405, 'Texas Instruments', 'TXN', '0.0726547716716422', 'Dallas, Texas')
# (406, 'Textron Inc.', 'TXT', '0.06597600706285738', 'Providence, Rhode Island')
# (407, 'The Bank of New York Mellon Corp.', 'BK', '0.02755871834376397', 'New York, New York')
# (408, 'The Clorox Company', 'CLX', '0.0316587792895062', 'Oakland, California')
# (409, 'The Cooper Companies', 'COO', '0.05246030715781069', 'Pleasanton, California')
# (410, 'The Hershey Company', 'HSY', '0.06847302086041779', 'Hershey, Pennsylvania')
# (411, 'The Mosaic Company', 'MOS', '-0.06180750754217405', 'Plymouth, Minnesota')
# (412, 'The Travelers Companies Inc.', 'TRV', '0.03514815289779835', 'New York, New York')
# (413, 'The Walt Disney Company', 'DIS', '-0.0008176714260218464', 'Burbank, California')
# (414, 'Thermo Fisher Scientific', 'TMO', '0.04739637230403695', 'Waltham, Massachusetts')
# (415, 'Tiffany & Co.', 'TIF', '0.021830429001591805', 'New York, New York')
# (416, 'TJX Companies Inc.', 'TJX', '0.022949411189305005', 'Framingham, Massachusetts')
# (417, 'Torchmark Corp.', 'TMK', '0.04657101596844067', 'McKinney, Texas')
# (418, 'Total System Services', 'TSS', '0.09303047946203531', 'Columbus, Georgia')
# (419, 'Tractor Supply Company', 'TSCO', '0.011517682542824346', 'Brentwood, Tennessee')
# (420, 'TransDigm Group', 'TDG', '0.06867300983322397', 'Cleveland, Ohio')
# (421, 'TripAdvisor', 'TRIP', '-0.011414099339224323', 'Newton, Massachusetts')
# (422, 'Twenty-First Century Fox Class A', 'FOXA', '0.02997389166554385', 'New York, New York')
# (423, 'Twenty-First Century Fox Class B', 'FOX', '0.019818091723219154', 'New York, New York')
# (424, 'Tyson Foods', 'TSN', '0.05406090658492564', 'Springdale, Arkansas')
# (425, 'U.S. Bancorp', 'USB', '0.02889341000258463', 'Minneapolis, Minnesota')
# (426, 'UDR Inc', 'UDR', '0.029821956731184023', 'Highlands Ranch, Colorado')
# (427, 'Ulta Beauty', 'ULTA', '-0.0188644029803224', 'Bolingbrook, Illinois')
# (428, 'Under Armour Class A', 'UAA', '-0.05279860826693622', 'Baltimore, Maryland')
# (429, 'Under Armour Class C', 'UA', '0.00812097451035633', 'Baltimore, Maryland')
# (430, 'Union Pacific', 'UNP', '0.04129058478691042', 'Omaha, Nebraska')
# (431, 'United Continental Holdings', 'UAL', '-0.012219428052289935', 'Chicago, Illinois')
# (432, 'United Health Group Inc.', 'UNH', '0.06705157387937428', 'Minnetonka, Minnesota')
# (433, 'United Parcel Service', 'UPS', '0.030799551713481355', 'Atlanta, Georgia')
# (434, 'United Rentals, Inc.', 'URI', '0.026105425678422785', 'Stamford, Connecticut')
# (435, 'United Technologies', 'UTX', '0.00043634444122630145', 'Hartford, Connecticut')
# (436, 'Universal Health Services, Inc.', 'UHS', '0.04533880508681282', 'King of Prussia, Pennsylvania')
# (437, 'Unum Group', 'UNM', '0.029553844881831035', 'Chattanooga, Tennessee')
# (438, 'V.F. Corp.', 'VFC', '0.04188328894372503', 'Greensboro, North Carolina')
# (439, 'Valero Energy', 'VLO', '0.03268422009857803', 'San Antonio, Texas')
# (440, 'Varian Medical Systems', 'VAR', '0.09312929253755402', 'Palo Alto, California')
# (441, 'Ventas Inc', 'VTR', '-0.02109282055943347', 'Chicago, Illinois')
# (442, 'Verisign Inc.', 'VRSN', '0.05082967911059135', 'Dulles, Virginia')
# (443, 'Verisk Analytics', 'VRSK', '0.05218141605001604', 'Jersey City, New Jersey')
# (444, 'Verizon Communications', 'VZ', '0.01274384141720009', 'New York, New York')
# (445, 'Vertex Pharmaceuticals Inc', 'VRTX', '0.011314528970183176', 'Cambridge, Massachusetts')
# (446, 'Viacom Inc.', 'VIAB', '-0.050897648155371095', 'New York, New York')
# (447, 'Visa Inc.', 'V', '0.014377316256128547', 'San Francisco, California')
# (448, 'Vornado Realty Trust', 'VNO', '0.006137249994922775', 'New York, New York')
# (449, 'Vulcan Materials', 'VMC', '0.01149372483497435', 'Birmingham, Alabama')
# (450, 'Wal-Mart Stores', 'WMT', '0.043401271760403884', 'Bentonville, Arkansas')
# (451, 'Walgreens Boots Alliance', 'WBA', '0.03453052750285998', 'Deerfield, Illinois')
# (452, 'Waste Management Inc.', 'WM', '0.05866756908449889', 'Houston, Texas')
# (453, 'Waters Corporation', 'WAT', '0.04728963309953722', 'Milford, Massachusetts')
# (454, 'Wec Energy Group Inc', 'WEC', '0.052885570858503116', 'Milwaukee, Wisconsin')
# (455, 'Wells Fargo', 'WFC', '0.0252859741876281', 'San Francisco, California')
# (456, 'Welltower Inc.', 'WELL', 'no', 'Toledo, Ohio')
# (457, 'Western Digital', 'WDC', '-0.005484551790533108', 'Irvine, California')
# (458, 'Western Union Co', 'WU', '0.04573763877978899', 'Englewood, Colorado')
# (459, 'WestRock Company', 'WRK', '-0.019761012296570735', 'Richmond, Virginia')
# (460, 'Weyerhaeuser Corp.', 'WY', '-0.00847665101156963', 'Federal Way, Washington')
# (461, 'Whirlpool Corp.', 'WHR', '0.018621666893723986', 'Benton Harbor, Michigan')
# (462, 'Williams Cos.', 'WMB', '-0.020901431194545468', 'Tulsa, Oklahoma')
# (463, 'Willis Towers Watson', 'WLTW', '0.04689740093612639', 'London, United Kingdom')
# (464, 'Wynn Resorts Ltd', 'WYNN', '-0.021907227134390295', 'Paradise, Nevada')
# (465, 'Xcel Energy Inc', 'XEL', '0.053817684238398104', 'Minneapolis, Minnesota')
# (466, 'Xerox Corp.', 'XRX', '-0.0037069311820936983', 'Norwalk, Connecticut')
# (467, 'Xilinx Inc', 'XLNX', '0.028418820360203816', 'San Jose, California')
# (468, 'Xylem Inc.', 'XYL', '0.04496349197236033', 'White Plains, New York')
# (469, 'Yum! Brands Inc', 'YUM', '0.03833095131260101', 'Louisville, Kentucky')
# (470, 'Zimmer Biomet Holdings', 'ZBH', '0.060902006695709124', 'Warsaw, Indiana')
# (471, 'Zions Bancorp', 'ZION', '0.032066888680273235', 'Salt Lake City, Utah')
# (472, 'Zoetis', 'ZTS', '0.01609880315307072', 'Florham Park, New Jersey')
